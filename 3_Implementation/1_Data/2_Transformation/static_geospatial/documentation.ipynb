# %% [markdown]
# # Geopackages list
#
# ### merged_pedologgia_static.gpkg
# - merged file that contains all relevant layers that will go in the aggregation
# ---
#
# ### pedologgia_cleaned.gpkg
# - pedologgia geopackage with removed layers and columns non relevant for the study
# ---
#
# ### pedologgia.gpkg
# - original pedologgia geopackage
# ---
#
# ### static_spatial_dimensions_cleaned.gpkg
# - all other collected sources aside from pedologgia, with removed layers and columns non relevant for the study
# ---
#
# ### static_spatial_dimensions.gpkg
# - all other collected sources aside from pedologgia as original
# ---
