# %% [markdown]
# # Sources to be extracted for the data cube

# %% [markdown]
# ## Causes
#
# - Seismic/site intensity
# - Rain mm
# - Temperature anomalies
# - Wind gust anomalies
# - Water levels in rivers
# - Water municipal distribution
# - (Not obtained yet) Wildfires (EFFIS)
# - Pendolarismo daily commuters dataset(ISTAT)(limited)
#
# ## Conditions
# - DTM’s and altitude peaks
# - Soil data, pedologia
# - Idrografia and water ways
# - Streets and flow infrastructure
# - Infrastructure
# - Idrological risk
# - Landslide risk
# - Natural zones
# - Forestal zones
# - Autorità di Bacino distrettuale dell'Appennino settentrionale Sentinel1 soil displacement points
#
# ## Effects
#
# - Interventions
# - Economical data
# - Population census
# - Landslides/Floods history
