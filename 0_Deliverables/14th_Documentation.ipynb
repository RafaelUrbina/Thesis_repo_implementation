# %% [markdown]
# # Documentation of 11th september
#
# ## General proyect details
#
# - Rounded results across the gpkg table
# - Rounded statistical results
# - Created a general preliminary documentation of the repository [Documentation](../Documentation.md)
# - Started writting the Data related section, "Data discovery" completed
#
# ## From past meeting
#
# - Created the script for the heatmaps and pair counts, (not runned yet)
# - Modified the Dim reduction for displaying the names of the highest relation between categorical vars (todo add the numerical highest and remove repeated vars) (not runned yet)
# - Modified the Dim reduction to extract the coordinates table and pair with the gpkg (Haven't done the cluster flagging to see the points in space)
#
# # Notes
#
# - Put the association rules as something that can be used for later since it has the direction of the association, for verify the link causes later after doing the connection with the patents
#
# - Topic modelling (for finding couple causes not seen before)
# - Sentiment analysis (for finding negative causes inside of the patents, used along side unicausal)
#
#
# ## TODO
#
# ### Weekend
# - Explain the plots as stated in [Past documentation](../0_Deliverables/13th_Documentation.ipynb)
# - Remove numerical duplicates
# - Add the numerical best pairings in the famd name display
# - Run the Heatmaps
# - Run the FAMD plot
# - FAMD feature importance highlight the ones with high correlation
# - FAMD check the var names of the two biggest sections to see the division logic what it is
# - Clusterize the famd coordinates and plot the result in qgis
#
# ### Da lunedi
# - Fine tune ontology to check the broader terms in the patent results
# - Check the paper - Unification of the phrases of the patents, approach with lists and unicausal - sentiment analysis
# - Terms matching from the lists to the patents (amount of matches for each patent, to see how the words are linked between eachother)
# - Check unicausal in the patents (Unsupervised, from the results already causal links, filter from the lexicon)
