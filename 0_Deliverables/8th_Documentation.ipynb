# %% [markdown]
# # Finished Query analysis and query formation, read the water 4.0, Main objectives updated, Satellite readings, data extractor

# %% [markdown]
# ## Query analysis and formation
#
# - [Ngram analysis for patents abstract](../2_Metadata_extraction/3_Patent_extraction/statistic_analysis.py)
#
# - [NER](../2_Metadata_extraction/3_Patent_extraction/NER_analysis.py)
#
# - [Final Query](../2_Metadata_extraction/3_Patent_extraction/query.txt)
#
# ## Main objectives and questions
#
# - Refer to the word document
#
# ## Water 4.0
#
# - delft FEWS (Risk assestment software)
#
# - NGSI-LD (model and api for big data handling)
#
# - EPANET (software for water distribution systems)
#
# - SCADA (industrial data aqcuisition and handling)
#
# - FIWARE (real time data handler)
#
# ## Satellite, UAV, Drone readings
#
# [Remote sensing for mapping buried pipelines](../1_Bibliography/2_Papers%20to%20review/1_(done)(important)remotesensingmappingburiedwaterpipelines.pdf)
#
# [Detection underground water leak](../1_Bibliography/2_Papers%20to%20review/1_(done)(important)scalabledetectionundergroundwaterleak.pdf)
#
# [Multitemporal remote sensing subterranean](../1_Bibliography/2_Papers%20to%20review/1_(done)(important)multitemporalremotesensingsubterranean.pdf)
#
# [Soil texture predictor](../1_Bibliography/2_Papers%20to%20review/1_(done)(important)Soil_Texture_Prediction_Advances.pdf)
#
# ### Tools for image extraction
#
# - Google earth pro
#
# - Sentinel-2
#
# - PlanetScope
#
# ### tools for soil information extraction
#
# - LUCAS topsoil datasets
#
# - SoilGrids (World soil information)
#
#
# ## Data extractor
#
# - It's extracting the files
#
# - Haven't implemented the failsafe for unavailable direct downloads through dati.gov webscraping
