# %% [markdown]
# # 7th Documentation
# ## (Objectives adjustment, Patent statistical analysis, Literature review, Data collector)
#
# ### Objectives adjustment
# - Check the shared document
#
# ### Query changes
# - Check the shared document
#
# ### Patent analysis
# - [N-gram analysis](../2_Metadata_extraction/3_Patent_extraction/statistic_analysis.py)
# - [NER analysis](../2_Metadata_extraction/3_Patent_extraction/NER_analysis.py)
#
# ### Literature review
# - Notes on shared material Water4.0 eht
# - [Irene shared documents](../1_Bibliography/3_Tables_lit_review/lit_table_json.ipynb)
# - [Satellite Query](../1_Bibliography/4_Notes/Bibliography_Notes.ipynb)
#
# ### Data extractor to go...
#
# ### Notes
# - Most reviews talk about integrations for single distribution systems or small closed quantities
# - All talk about propietary data inside their premises
# - delft FEWS a system build for prediction of flood risks, open source, used in various water system solutions today (quality and flow)
# - Satellite solutions seem like thesis proposals by themselves (broad spectrum of how big the thesis is going to be)
# - Patents query can get refinement with the new analytic results but is close to being done
# - Aggregated data extractor and literature about satellites, drones, still in progress
