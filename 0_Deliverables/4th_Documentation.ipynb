# %% [markdown]
# #### 4th documentation before christmas
#
# - Extract more datasets from southern regions
#     - Generated the pipelines to use CKAN API and extract information automatically for metadata and resources metadata for: DATI.GOV, Calabria, Campania, Lazio, Puglia, Sicilia, Umbria
# - Give explanaition to umap representation
#     - Runned an extremes samples analysis to see what is contained in the outter most points for each corner of the 2d space
# - Remove wordcloud classes and plot only the data sources
# - Re name cannonical labels
#     - To better represent the data types used
# - Change the multimodal label visual positions
#     - To show it as notes and not as a cannonical label in itself
# - Sort the barplots
# - Deagregate dati.gov
#     - By extracting better metadata from datigov the deagregation of domains and sources was possible
# - Clean app dashboard
#     - Loaded most of the plots as images
