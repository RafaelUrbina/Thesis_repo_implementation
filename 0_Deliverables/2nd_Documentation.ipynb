# %% [markdown]
# ## Finalizing the initial collection of data and article sources
#
# ---------

# %% [markdown]
# ## After the last meeting (corrections)
# * Re checked Literature review tables to find and correct any errors.
# * Reworked Scopus query to have a more specific structure [query](../../Thesis_repo/1_Bibliography/4_Notes/Bibliography_Notes.ipynb).
#
# -------------
#
# ## Things done these last days
# * Created the data related table for the literature review [data literature review](../../Thesis_repo/1_Bibliography/3_Tables_lit_review/data_rev_py.ipynb) (Added all sources with information on their methodology and data it deals with).
# * Created the data sources [table](../../Thesis_repo/2_Data_extraction/Data%20tables/Table_dat_py.ipynb) for the sources collected on [ISTAT](../../Thesis_repo/2_Data_extraction/0_preliminary_data_sources/ISTAT.ipynb) , [EUROSTAT](../../Thesis_repo/2_Data_extraction/0_preliminary_data_sources/EUROSTAT.ipynb) and [MISC](../../Thesis_repo/2_Data_extraction/0_preliminary_data_sources/MISC.ipynb) a total of 274 sources where documented in the table as of today 25/11/2025.
#
#     - (Some of the websites contain API access which was used to extract meta data, and could also be used to bulk download data we might need).
#     - Some of these sources are: dati.gov.it, Copernicus, Istat, Eurostat, idrogeo.isprambiente.it, cfti.ingv.it, Espacenet(query limitations, haven't tested), distrettoalpiorientali.it
#     -metadata was generally downloaded without many errors, also didnt encountered any requests limitations like 'too many requests', I assume this could be because it's just the meta data, while downloading the actual datasets I would assume there should be query limits.
#
# * Added 4 more articles to the literature review table (with a current total of 25), which are found with the new Sopus query, the new articles found are more specific to the field we are tackling ex: [Hydrosense](../../Thesis_repo/1_Bibliography/2_Papers%20to%20review/1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf),  [DAG's for predictive maiuntenance in hidric systems](../../Thesis_repo/1_Bibliography/2_Papers%20to%20review/1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf).
#
# * Updated the Scopus analysis in [Scopus Folder](../../Thesis_repo/1_Bibliography/3_Tables_lit_review/Scopus%20analysis/).
#
# --------------
#
# ## Things to do
#
# * Create some meta analysis about the data collected.
#
# * Start consolidating the data that would be used for a preliminary integration.
