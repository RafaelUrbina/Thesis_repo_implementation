# %% [markdown]
# # Documentation for 25th september
#
# ## [Bar charts](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/py/table_plots.py)
#
# - Was created to output 3 bar charts showing the most occurrent: Technical terms, Attributes and Failure terms. [Technical](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/term_frequencies/top_technical_terms.png) , [Attributes](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/term_frequencies/top_attribute_terms.png) , [Failures](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/term_frequencies/top_failure_terms.png)
#
# ## [Summary statistics](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/py/summary_statistics.py)
#
# - A set of summary statistics was created where the top association pairs are displayed [top associations Technical vs Attributes](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/top_associations_tech_vs_attr.csv) and [top associations Attributes vs Failures](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/top_associations_attr_vs_fail.csv) and [top associations Verbs vs Failures](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/top_associations_verb_vs_fail.csv)
#
# ## [Heat maps](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/py/summary_statistics.py)
#
# - Heat maps where created to see in better detail the npmi of the most frequent pairs for [technical terms vs attribute terms](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/heatmap_top20_tech_vs_attr.png) and [attribute terms vs failure terms](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/heatmap_top20_attr_vs_fail.png) ,
# and [Verbs vs failure terms](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/heatmap_top20_verb_vs_fail.png)
#
#
# ## [Summary intra patent](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/py/summary_statistics.py)
#
# - Runned a occurrence table for the key occurrences and which links are created intra patent [summary patent](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/summary_statistics/patent_summary_cards.csv)
#
# ## [Partial causal links](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/py/network_partial_causes.py)
#
# - Created partial links between Technical terms -> Attribute terms -> Failure terms. [here](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/causal_graph/patent_edge_cases_sankey.html)
#
# - Created a second partial link chain with nouns and verbs. [here](../3_Implementation/2_Data_analysis/patents/pipeline/knowledge_abstract/output/causal_graph/patent_edge_cases_pos_sankey.html)
