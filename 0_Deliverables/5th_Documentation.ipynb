# %% [markdown]
# # 5th documentation (First of the year)
# ---
#
# ## Updating the dashboard
# - Updated the values and plots
# - Added the filter for the columns of the table
# - Changed the map plot to have the colourpalette in logarithmic scale but show the values in original vals
# - Changed the composition of the labels to be percentage wise
# - Added two dimensions of Cannonical labels, the types one and the use one
#
# ## Started Patent search
# - Found relevant classes
# - Started search on WIPO with preliminary query
# - Started search on Lens with preliminary query
# - Refined the query but still needs some adjustments
# - Downloaded some schemas for how the patent metadata could look
#
# ## Created the Dashboard to present to Fantoni
# - Created the Dashboard
# - I have things to modify on the dashboard
