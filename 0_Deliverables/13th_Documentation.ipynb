# %% [markdown]
# # Progress from the second part of august (for 4th sept)
#
# * Finished the pipeline for ESDA [univariate](../3_Implementation/2_Data_analysis/spatial_correlation/py/spatial_autocorrelation_analysis.py) and [multivariate](../3_Implementation/2_Data_analysis/spatial_correlation/py/multivariate_spatial_analysis.py)
#
# * Enriched the terms lists [terms folder](../3_Implementation/2_Data_analysis/patents/links_lists/todo_enrich_terms.md)
#
# * Created a draft ontology and found repositories on the web which could add context [file](../3_Implementation/2_Data_analysis/patents/ontology/py/ontology.py).
#
# * Started writting the proyect document
#
# * Drafted the link methodology idea [idea](../Data_to_patent_link_methodology.md)

# %% [markdown]
# ## Todo
#
# * Check decimal for all results in repo
#
# * Create the repo documentation, clean any non used files
#
# * Create summary statistics for the report
#
# * Continue (start) with chapter 3 data related
#
# * Study the UniCausal model
#
# * Study the mentioned external ontologies and fine tune the ontology script
#
# *   - Numerical stats
#     explain the 3 plots: climatological, geological and social
#     explain the autocorrelation of the ones for the bivariate as well so 6
#     - Categorical stats
#     explain the first 10 associations for categorical vars, and also the auto associations
#     generate a heatmap on the h3 grid for every pair of the categorical variables (pair count plot or so)
#     -Layer to get
#     check the destinazione d'uso layer
#     get the communal layer
#     - FAMD
#     Inside the FAMD, highlight the 6 numerical and 6 categorical vairables only, show the full name.
#     Get the table from the dim reduction, with the coordinates generate the rule to separate both clusters, try to pair with the shape attribute of the original geopackage, plot the results in qgis.19:00
