# %% [markdown]
# ### 1. Presenting the [dashboard](../../Thesis_repo/3_Data_analysis/9_app.py)

# %% [markdown]
# * created to show some insights about all the information that was captured
# * Things for improvement:
#     - Create a bigram or trigram model to analyze sentences on the cleaned text for sources and articles
#     - Dig deeper in the matched articles and their composition
#     - Analyze deeper the composition of the clustered group where all the articles reside.

# %% [markdown]
# ### 2. Emphasize on the need for more granular time series data

# %% [markdown]
# * Types of sensors used in relevant articles:
#     - Accelerometers, strain gauges, acoustic emission, Turbidity, Preassure, Solids disolved,  piezoelectricultra sonic,       impedance-based, wave-propagation method, temperature, leakage, chemical leakage,

# %% [markdown]
# - WE COULD: research how to make an asociation with some of the ARPAs in order to obtain raw granular data about the sensors they employ.
#     - The specific ARPA we contact depend on what the meta analysis of the data sources yields, since that way we can choose already data rich regions which we can enrich even more with this ARPA granular data.

# %% [markdown]
# ### 3. A very relevant paper for our case

# %% [markdown]
# - [Water wise – a digital water solution for smart cities and water management entities](../../Thesis_repo/1_Bibliography/2_Papers%20to%20review/1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf) (I tried to fin a similar idea for the italian case, with no luck)
#
# - Other ideas found: Use socialmedia posts or tweets which contain geolocations to predict water conditions [A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities](../../Thesis_repo/1_Bibliography/2_Papers%20to%20review/2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf) they do it for flooding and natural disasters.
