# %% [markdown]
# # Geo data acquisition, cleaning in Qgis and loading in python for further cleaning

# %% [markdown]
# ## Finished the new patents query
#
# - Total query 26,824
# - Sub query 8,055 (external risks patents found)
# - Re runned the Ngram analysis (similar words results, no new words to add in the query found)
# - Re runned the NER analysis (no new words to add in the query found)

# %% [markdown]
# ## Geo data acquisition
#
# - checked how to use each source in a better way
# - acquired all sources from the final sources list
# - loaded all sources to check the validity of them

# %% [markdown]
# ## Cleaning in Qgis
#
# - check the region limits
# - filtered data for only firenze province
# - runned validity analysis of each geometry sanity
# - transformed all layers to normalized CRS EPSG WGS84 32632 metric coordinate system
# - cleaned styles in qgis for better visibility
# - created two separate geopackages (GPKG) first is the general data extracted which contained geospatial elements, second is a package made of the pedologgia geometries
# - Filtered rasters for DTM on idrologia for firenze
# - Saved idrologia, spectral, slope DTM's as tiff's for zonal statistics

# %% [markdown]
# ## Python
#
# - Loaded the geopackages
# - Created a temporary script to drop the useless columns sequentially
# - Still the cleaning to go
