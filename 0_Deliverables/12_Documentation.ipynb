# %% [markdown]
# # Final sources extraction and integration into geopackage

# %% [markdown]
# ## Sources
#
# - Idrometria
# - Anemometria
# - Termometria
# - Pendolarismo
# - Sentinel-1 Soil displacement
#
# ## Cleaning
#
# - Aggregating sources to geopackage
# - Merging pedologgia and static sources
# - Explode all the multilayers
# - Aggregate some layers for easier grid integration (ISPRA pericolo)
#
# ## Structural process
#
# - Connect weather tabular data to geospatial
# - Connect socio/economic data to geospatia
# - Run zonal statistics for raster data
