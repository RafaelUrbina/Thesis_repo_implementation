# %% [markdown]
# # 6th Documentation (Restarting work)
#
# ### Catching up to what has been done until end of January (Vacations)
# - [Slides](../4_Slides/Water%20transport%20slides.pdf)
#
# ### Finished the patent query for metadata extraction
# - [Selected query](../2_Metadata_extraction/3_Patent_extraction/query.txt) was created by analyzing the IPC classes, relevant key terms, irrelevant topics for the search and regular expressions that help filter the patents (Can be seen better through The lens.org website)
#
# ### Started the dataset extraction
# - Istat bulkdownload of the selected datasets [done](/6_Dataset_acquisition/ISTAT/0_extractor.ipynb)
# - Eurostat bulkdownload of the selected datasets [done](/6_Dataset_acquisition/EUROSTAT/0_extractor.ipynb)
# - Aggregated sources extraction [started](/6_Dataset_acquisition/Aggregated_sources/1_extractor.py) (I still need to fine tune the extraction process for the highly heterogeneous nature)
