# %% [markdown]
# # Methods names that might be useful during the thesis

# %% [markdown]
# - RDF (Resource Description Framework)
#
# - Attention mechanisms in ML
#
# - Ontology in ML
#
# - Knowledge graphs
#
# - Data fusion mechanisms
#
# - Multimodal sources
