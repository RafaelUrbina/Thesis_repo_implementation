# %% [markdown]
# -----
#
# ## Literature Review Summary Table
#
# | Authors | Title | Year | Keywords | General Idea (Short and Brief) | Objective of the Article | Future Work or Improvements | Journal/Publication | Source File Name |
# | :--- | :--- | :---: | :--- | :--- | :--- | :--- | :--- | :--- |
# | Jihong yan, Yue meng, Lei lu, Lin li | Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance | 2017 | Industrial Big Data, Predictive Maintenance, Multisource heterogeneous data, Structuralization and characterization, Multiple invisible factors | (Cites relevant papers useful for our basis) Reviews the challenges, schemes, and applications of **Industrial Big Data** within the Industry 4.0 environment, with a focus on **Predictive Maintenance**. | To present a summary of the challenges, schemes, and applications of Industrial Big Data for Predictive Maintenance in the context of Industry 4.0. | Not explicitly mentioned. | IEEE Access | [1\_(done)(irene)Industrial\_Big\_Data\_in\_an\_Industry\_4.0\_Environment\_Challenges\_Schemes\_and\_Applications\_for\_Predictive\_Maintenance.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf) |
# | Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr | Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies | 2019 | Digitization, Technology, Industry 4.0 | (Cites relevant papers useful for our basis) A systematic review defining Industry 4.0 as a **data-driven paradigm** and identifying 111 associated technologies, grouped by their function (generation, transmission, processing, application). | To explain the complex nature of Industry 4.0 by developing a framework that groups and links its identified technologies based on their data functions. | **Intensify research into Data Application technologies**. **Explore relationships between technologies using Social Network Analysis**. | Journal of Manufacturing Technology Management | [1\_(done)(irene)Industry4 as data-driven and technologies 2021.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)Industry4%20as%20data-driven%20and%20technologies%202021.pdf) |
# | Lian Duan, Li Da Xu | Data Analytics and Industry 4.0: Survey | 2021 | Industry 4.0, Data Analytics, Big Data, Cloud computing, Internet of things, Cyber-physical Systems (CPSs), Manufacturing, Digital Twin, 5G, Blockchain | (Cites relevant papers useful for our basis) Discusses the necessity and benefits of merging **Industry 4.0 and Data Analytics** (routine operations meeting smart decisions) and reviews existing research trends in this intersection. | To study the basic concepts, benefits, and interaction between Industry 4.0 and Data Analytics, and conduct a systematic review to understand the research focus and trend. | Continue joint research on different intersections with different components (industry sectors, CPSs, and analytic methods). | Information Systems Frontiers | [1\_(done)(irene)data analytics industry4 survey 2024.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)data%20analytics%20industry4%20survey%202024.pdf) |
# | Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider | 5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models | 2021 | Applications, classifications, cross-industry, description, Digital Twin, model | Proposes a structured model for Digital Twin applications based on a sequence of five steps: Scope Physical, Features of Physical, Data communication, Scope virtual, Value output. | To analyze Digital Twin classification terms and models, and propose a new structured framework (the 5-dimension model implemented from Grieves) for DT applications. | Not explicitly mentioned. | IEEE Access | [1\_5-Dimension\_Cross-Industry\_Digital\_Twin\_Applications\_Model\_and\_Analysis\_of\_Digital\_Twin\_Classification\_Terms\_and\_Models.pdf](../2_Papers%20to%20review/1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf) |
# | Weiming Liu, Chen Zhang, Bin Yu, Yitong Li | A General Multi-Source Data Fusion Framework | 2019 | Multi-source data, Data fusion, RDF (Resource Description Frame work), Data matching, Conflict resolution | Proposes a general **four-layer framework** based on an improved **RDF (Resource Description Framework)** to integrate heterogeneous multi-source data and resolve heterogeneity and semantic conflicts. | To propose a general four-layer framework to solve heterogeneity and semantic conflicts in multi-source data fusion and improve the original RDF-based data fusion framework. | Will work on **conflict resolution methods for multi-language application scenarios** in follow-up works. | Association for Computing Machinery (ACM) | [1\_A General Multi-source data fusion framework.pdf](../2_Papers%20to%20review/1_A%20General%20Multi-source%20data%20fusion%20framework.pdf) |
# | Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan | A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion | 2022 | Stock prediction, Graph data, Graph neural network, Multi-source data | Proposes a graph-based model utilizing GNN and attention mechanisms to fuse heterogeneous data (transaction metrics and financial news text obtained via web crawling) for predicting stock market fluctuations. | To achieve classification prediction of stock market fluctuations by employing a graph-based approach to fuse multi-source heterogeneous information. | **Expand to multi-attention mechanisms**, further study the interaction mechanism between multi-source heterogeneous data. | Multimedia Tools and Applications | [1\_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf](../2_Papers%20to%20review/1_A%20graph%20neural%20network-based%20stock%20forecasting%20method%20utilizing%20multi-source%20heterogeneous%20data%20fusion.pdf) |
# | Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee | Enabling technologies and tools for digital twin | 2021 | Digital twin, Five-dimension model, Enabling technologies, Enabling tools | A review detailing the architecture, components, and **tools required to implement the Digital Twin** concept, placing it within the context of CPS and Industry 4.0. | To review and analyze the technologies and tools that enable the Digital Twin, including its architecture and correlation with CPS and Industry 4.0/Smart Manufacturing. | Not explicitly mentioned. | [ScienceDirect] Journal of Manufacturing Systems | [1\_Enabling technologies and tools for digital twin.pdf](../2_Papers%20to%20review/1_Enabling%20technologies%20and%20tools%20for%20digital%20twin.pdf) |
# | Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao | FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data | 2024 | On-demand Fusion Queries (OD-FQ), Multi-source Heterogeneous Data, Between-source Conflicts, Data Veracity, Source Trustworthiness | Presents **FusionQuery**, an efficient framework using knowledge graph matching and an iterative EM-style algorithm to perform **real-time data fusion** and resolve conflicts only on query-related heterogeneous data. | To address the limitations of batch data fusion by proposing and evaluating an effective and scalable system for handling on-demand fusion queries over heterogeneous multi-source data, examples on how LLM's can fact check information more efficiently. | Plan to further **enhance the effectiveness of the on-demand fusion query**. | PVLDB (Proceedings of the VLDB Endowment) | [1\_FusionQuery-On-demand Fusion Queries.pdf](../2_Papers%20to%20review/1_FusionQuery-On-demand%20Fusion%20Queries.pdf) |
# | Simon Kamm, Nasser Jazdi, Michael Weyrich | Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches | 2021 | Heterogeneous Data, Industry 4.0, Internet of Things, Knowledge Discovery, Machine Learning, Semantic Data Integration, Unstructured Data | Discusses challenges for **Knowledge Discovery (KDD)** in Industry 4.0 due to the increasing volume and heterogeneity of data, which often results in separated "data silos". | To identify and analyze the challenges and necessary approaches for Knowledge Discovery in Industry 4.0 systems dealing with heterogeneous and unstructured data. |Detailed concretization and comparative analysis of existing approaches. This work will specifically target industrial automation systems operating under challenging environmental conditions, such as strict timing requirements or distributed partial processes. | Procedia CIRP | [1\_Knowledge discovery in heterogeneous and unstructured data.pdf](../2_Papers%20to%20review/1_Knowledge%20discovery%20in%20heterogeneous%20and%20unstructured%20data.pdf) |
# | Theofanis P. Raptis, Andrea Passarella, Marco Conti | Data Management in Industry 4.0: State of the Art and Open Challenges | 2019 | Data management, industrial networks, manufacturing, Industry 4.0 | (Cites relevant papers useful for our basis) A survey reviewing data management issues (2015-2018) in **networked industrial environments (Industry 4.0)**, classifying relevant technologies and services. | To survey the literature and identify open challenges for data management in the intersection of industrial automation and communication/networking fields. | Open challenges include: **Energy efficient data delivery**; **Data distribution in local and mobile clouds**; **Distributed, real-time data security**; and Convergence between communications and industrial automation. | IEEE Access | [2\_(done)(irene)Data\_Management\_in\_Industry\_4.0\_State\_of\_the\_Art\_and\_Open\_Challenges.pdf](../2_Papers%20to%20review/2_\(done\)\(irene\)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf) |
# | Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang | A Survey on Deep Learning for Multimodal Data Fusion | 2020 | Deep Learning (DL), Multimodal Data Fusion, DBN, SAE, CNN, RNN, Semantic Fusion Strategies | Surveys Deep Learning models designed for **multimodal data fusion**, categorizing approaches based on architectures like Deep Belief Networks (DBN) and Recurrent Neural Networks (RNN) among others. | To provide an overview and summarize deep learning models developed for multimodal data fusion, built on current representative DL architectures. | New DL models that take semantic relationships into consideration are urgently needed. Suggests combining deep learning with **semantic fusion strategies**. | Neural Computation | [2\_deeplearning\_multimodal.pdf](../2_Papers%20to%20review/2_deeplearning_multimodal.pdf) |
# | Jun Wang, Xiaohan Li, Huading Jia, Tao Peng | A graph-based approach to multi-source heterogeneous information fusion in stock market | 2022 | Graph fusion, Heterogeneous information/data, Relational dimension, Multi-attention graph neural network, Stock market price fluctuation/prediction, Complex network, Information spillover | Proposes a graph fusion and embedding method using a multi-attention GNN to incorporate multi-source heterogeneous data and relational information for predicting stock market volatility. | To establish a graph fusion and embedding method using relational dimension information for fusing heterogeneous data, and construct a GNN to mine implied semantics for stock price prediction. | Expand node features (e.g., trading data derivative index, graphical data) and study the interaction mechanism of heterogeneous data. Explore building a public opinion monitoring function for securities market regulation. | PLoS ONE | [2\_graph-based multisource heterogeneous information fusion for stockmarket.pdf](../2_Papers%20to%20review/2_graph-based%20multisource%20heterogeneous%20information%20fusion%20for%20stockmarket.pdf) |
# | Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui | Multi-Source Information Fusion Based Heterogeneous Network Embedding | 2020 | Heterogeneous Network Embedding, Multi-Source Information Fusion, Representation Learning, Joint Learning | Proposes MIFHNE, a generic approach to enhance network embedding by integrating rich multi-source information (structural, semantic, attribute, and label data) in Heterogeneous Information Networks (HINs). | To propose and validate the MIFHNE approach, demonstrating the importance of multi-source information fusion for network embedding in HINs. | Future work is presented in Section 6. (will focus on the possibility of the attribute information of node being multimodal, basis for designing an efficient embedding method for heterogeneous network) | [ScienceDirect] Information Sciences | [2\_multisourceinformationfusionbasednetworkingembedding.pdf](../2_Papers%20to%20review/2_multisourceinformationfusionbasednetworkingembedding.pdf) |
# | Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli | Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction | 2021 | Heterogeneous data sources, Data fusion, Radial Basis Functions (RBF), Deep Learning, Graph Convolutional Networks (GCN) | Describes a data fusion pipeline where raw heterogeneous data is preprocessed/fused (e.g., via RBF function), then modeled using various ML Model (GCN/GCNN/STGCN) architectures for prediction. | To construct a pipeline for heterogeneous data fusion and modeling using graph convolutional network architectures dedicated to AirQuality prediction. | Not explicitly mentioned. | Journal of King Saud University - Computer and Information Sciences | [3\_datafusion\_graphCNN.pdf](../2_Papers%20to%20review/3_datafusion_graphCNN.pdf) |
# | Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang | Multi-source Heterogeneous Data Fusion Model Based on FC-SAE | 2022 | Multi-source heterogeneous, Data fusion, Deep learning, SAE, FC | Proposes the FC-SAE model (Fully Connected Sparse Autoencoder) as a fusion mechanism to integrate time-series data and text data for enhanced forecasting accuracy. | To propose an FC-SAE based multi-source heterogeneous data fusion model that breaks the structural barrier between time series data and text data. | Not explicitly mentioned. | Journal of Internet Technology | [4\_datafusion\_multisource.pdf](../2_Papers%20to%20review/4_datafusion_multisource.pdf) |
# | Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth | A Multimodal Approach for Semantic Patent Image Retrieval | 2021 | Patent Image Similarity Search, Deep Learning, Mulitmodal Feature Representations, Scene Text Spotting | Presents a multimodal retrieval system for patent images that extracts and fuses both textual features (from figure descriptions) and visual features (from images) using **score re-ranking**. | To evaluate and improve the relevance of patent retrieval results using the multimodal feature fusion derived from patent images and their associated textual descriptions. | Plan to exploit further information in images (e.g., non-numeric image text). Intend to incorporate multimodal information in an end-to-end network or joint framework. | PatentSemTech | [5\_multimodal\_patentimage.pdf](../2_Papers%20to%20review/5_multimodal_patentimage.pdf) |
# | Jeonghun Jee, Sanghyun Park, Sungjoo Lee | Potential of patent image data as technology intelligence source | 2022 | Patent analysis, Image data, Technology intelligence, Product structure, Network analysis, Block diagrams | Investigates the potential of **texts extracted specifically from patent block diagrams (images)** as a crucial source of technology intelligence for structural analysis. | To investigate the potential of patent image data, particularly text from block diagrams, to be used as a source of technology intelligence. | Requires a more elaborated method for identifying meaningful terms using **n-grams or pre-defined dictionaries**. Future study needed to customize the approach to various other types of patent drawings. Investigate the potential value of combining subject-action-object (SAO) analysis with image analysis. | [ScienceDirect] Journal of Informetrics | [6\_patentimage.pdf](../2_Papers%20to%20review/6_patentimage.pdf) |
# | Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao | Research on product appearance patent spatial shape recognition for multi-image feature fusion | 2023 | Design Patent Search System, Spatial Shape Recognition, Multi-image fusion, Image Segmentation, Contour Description (Inferred) | Describes the system design and user interface functionality for a design patent search system specializing in spatial shape recognition, which relies on analyzing and fusing multiple images/views. | To demonstrate a system and methodology for retrieving design patents based on spatial shape recognition using multi-image fusion. | Not explicitly mentioned. | [Springer] Multimedia Tools and Applications | [7\_patentimage\_spatialshapes.pdf](../2_Papers%20to%20review/7_patentimage_spatialshapes.pdf) |
# | Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang | Multi-source heterogeneous data fusion | 2018 | Big data, Heterogeneous data, Data fusion, Heterogeneous data fusion, Deep learning | Overview of the problems, challenges, and technologies associated with multi-source data fusion in the context of Big Data, referencing methodologies like Ensemble Learning and Deep Learning approaches. | To overview problems and challenges associated with Big Data fusion, particularly emphasizing Deep Learning models for fusing heterogeneous sensor data. | Not explicitly mentioned. | IEEE Xplore | [8\_Multi-source\_heterogeneous\_data\_fusion.pdf](../2_Papers%20to%20review/8_Multi-source_heterogeneous_data_fusion.pdf) |
# | Sultan Baimukhanov, Hashim Ali, Adnan Yazici | Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing | 2025 | IoT-Cloud Interaction, Data management in IoT, IoT security vulnerabilities, Anomaly detection, Explainable AI | Proposes a system (SSPA) integrating Machine Learning (ML), IoT, Cloud Computing (CC), and Edge Computing (EC) to enhance anomaly detection specifically for security and data management in IoT environments. The system uses the iForest algorithm for anomaly detection. | To explore the potential of integrating ML, IoT, CC, and EC to improve anomaly detection in data management and substantiate the practical applicability and viability of the proposed solution. | Not explicitly mentioned. | [ScienceDirect] Expert Systems With Applications | [2\_Enhancing\_MLbased anomaly detection in data management for security on integration of iot.pdf](../2_Papers%20to%20review/2_Enhancing_MLbased%20anomaly%20detection%20in%20data%20management%20for%20security%20on%20integration%20of%20iot.pdf) |
# | Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza | Artificial Intelligence in manufacturing: State of the Art, Perspectives, and Future Directions | 2024 | Artificial intelligence, Smart manufacturing, Machine learning | Reviews state-of-the-art AI applications (model-based & data-driven) across the manufacturing lifecycle (design, process, quality, assembly) to guide the realization of smart manufacturing (well updated and analyzing current trends). | To present advances in AI in manufacturing with an integrated view of system, process, quality, and (dis)assembly, map AI technologies to manufacturing tasks, and outline emerging challenges and future directions. | Expand on unsupervised learning, **integrating physics with AI**, developing **causal AI**, adopting next-generation **Generative AI** and **Generalist AI models (LLMs)**, researching **AI-specific hardware**, and focusing on **real-life AI introduction** (trustworthiness). | [ScienceDirect] CIRP Annals - Manufacturing Technology | [1\_(irene)\_ArtificialIntelligence\_In\_manufacturing\_state\_of\_art\_futuredirections.pdf](../2_Papers%20to%20review/1_(done)(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf) |
# | Amit Mithal, Blessy Thankachan | A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management | 2025 | **Blockchain Technology**, **Machine Learning (ML)**, **Deep Learning (DL)**, Groundwater Conservation, Wastewater Management, **Data Integrity**, Anomaly Detection, Resource Optimization, Regulatory Compliance | A systematic review (2019-2025) of 97 peer-reviewed articles analyzing the convergence of **Blockchain, ML, and DL** to enhance sustainability, maintain **data integrity**, and optimize resource utilization in the water sector. | To systematically analyze recent technological advances, evaluate performance improvements achieved through Blockchain/AI integration, and identify critical research gaps and future directions for sustainable water resource management. | The abstract confirms the identification of **research gaps and future directions** (e.g., improved data validation, resource optimization, transparency). | Environmental Management | [1\_(Important)A review on blockchain for water mngmnt.pdf](../2_Papers%20to%20review/1_\(Important\)A%20review%20on%20blockchain%20for%20water%20mngmnt.pdf) |
# | Nikita V. Golovastikov, Nikolay L. Kazanskiy, and Svetlana N. Khonina | Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure | 2025 | Optical Fiber Sensors (OFS), Structural Health Monitoring (SHM), Dams, Pipelines, Distributed Acoustic Sensing (DAS), Water Management, Artificial Intelligence (AI) | A comprehensive review of **Optical Fiber Sensors (OFS)** for **Structural Health Monitoring (SHM)**, specifically detailing their application in monitoring the structural integrity, seepage, leakage, and dynamic conditions of **dams, water management infrastructure, and long-distance pipelines**. | To review the latest advancements, applications, and integration of OFS and AI/Machine Learning techniques for SHM in civil and urban infrastructure, including critical water assets. | **Develop more dynamic Digital Twin models for real-time monitoring**. **Establish standardization of test procedures and calibration for OFS**. | Photonics | [3\_Optical Fiber-Based Structural Health Monitoring.pdf](../2_Papers%20to%20review/3_Optical%20Fiber-Based%20Structural%20Health%20Monitoring.pdf) |
# | Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu | Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0 | 2025 | Directed Acyclic Graphs (DAGs), Ensemble Learning, Predictive Maintenance, Industry 4.0, Machine Learning, Failure Prediction | Proposes a novel approach using **Directed Acyclic Graphs (DAGs)** to **ensemble multiple machine learning models**, enabling more robust and accurate failure predictions for **Predictive Maintenance** in Industry 4.0. | To propose a novel approach using Directed Acyclic Graphs (DAGs) to ensemble multiple machine learning models, enabling more robust and accurate failure predictions. | Not explicitly mentioned in the abstract. | 2025 International Conference on Next Generation Communication & Information Processing (INCIP) | [1\_(important)Leveraging\_Directed\_Acyclic\_Graphs\_for\_Advanced\_Ensemble\_Learning\_in\_Predictive\_Maintenance\_for\_Industry\_4.0.pdf](../2_Papers%20to%20review/1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf) |
# | Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A | HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration | 2025 | IoT, Water Quality Monitoring, Machine Learning, Cloud Integration, ESP32, Real-time Alerts, Public Health | Presents HydroSense 2.0, an intelligent water quality monitoring system using **IoT sensors (pH, temperature, turbidity, TDS)**, an ESP32 microcontroller, and **machine learning models** for real-time surveillance and automated alerts. | To develop and deploy a comprehensive, real-time, automated water quality surveillance system (HydroSense 2.0) integrated with cloud computing and machine learning to address public health and safety concerns. | Not explicitly mentioned in the abstract. | 2025 International Conference on Computing Technologies & Data Communication (ICCTDC) | [1\_(important)HydroSense\_2.0\_An\_IoT-Based\_Smart\_Water\_Quality\_Monitoring\_and\_Alert\_System\_with\_Machine\_Learning\_and\_Cloud\_Integration.pdf](../2_Papers%20to%20review/1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf) |
# | Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami | Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights | 2021 | Structural health monitoring, machine learning, internet of things, big data, emerging technologies | A review clarifying and summarizing the Machine Learning (ML) pipelines and frontiers in modern Structural Health Monitoring (SHM) systems, with a focus on emerging technologies like IoT, Big Data, UAVs, AR/VR, and Digital Twins. | To clarify and review the ML frontiers involved in modern SHM systems, detailing ML pipelines, tools, and algorithms, and exploring the connection to next-generation technologies and data science prospects for SHM. | The article examines current and future challenges and open research issues in the SHM-ML conjunction and offers an outlook on the future of monitoring civil infrastructure integrity. | Structural Health Monitoring | [3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf](../2_Papers%20to%20review/3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf) |
# | Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam | Big Data analytics and IoT in Operation safety management in Under Water Management | 2020 | Big Data Analytics, Internet of Things, Water management, Sensors, WSN | The paper proposes a Supervisory Control and Data Acquisition (SCADA) approach using IoT and Big Data Analytics for sustainable smart water management. Experimental results demonstrate that this implementation proactively controls water usage and achieves higher levels of sustainable water supply. | To propose a Mathematical model and demonstrate the Supervisory Control and Data Acquisition (SCADA) method for smart water management using IoT and Big Data Analytics, including remote environmental monitoring using Raspberry Pi and Python. | The authors recommend developing more models using Big Data and IoT for long-term evaluation and scheduling of water distribution networks, performing multi-periodic leakage stream analysis, and expanding performance analyses to include natural and man-made disasters (e.g., earthquakes, thefts, and terrorism). | Computer Communications | [2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf](../2_Papers%20to%20review/2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf) |
# | N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas | A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities | 2020 | Internet of things, Flood analytics information system, Machine learning, Big Data, Flood situational awareness | Presents a national-scale Flood Analytics Information System (FAIS) as a Python Web application. This system gathers Big Data from multiple sources, integrates crowd intelligence, Machine Learning (ML), and Natural Language Processing (NLP) of tweets to provide flood warnings and improve situational awareness for flood risk management. | To develop and demonstrate the capabilities of the Flood Analytics Information System (FAIS) to assess flooding impacts during historical and real-time events by leveraging IoT, Big Data, ML, and crowd-sourced intelligence. | The paper suggests expanding the system's spatial coverage (beyond The Carolinas) and integrating more detailed infrastructure and socio-economic data for improved vulnerability assessments. | Environmental Modelling and Software | [2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf](../2_Papers%20to%20review/2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf) |
# | Inês Figueiredo, Paulo Esteves, Paulo Cabrita | Water wise – a digital water solution for smart cities and water management entities | 2021 | Digital water, Smart cities, Water management, Water-Energy Nexus, IoT, Decision support system | Presents the 'Water Wise System' (W2S), a digital water solution developed to efficiently manage the urban water cycle. The system utilizes real-time monitoring, a decision support system, and addresses the water-energy nexus for smart cities. | To present a preliminary study of the architecture and software solution for the Water Wise System (W2S), focusing on water management challenges, available technology, Digital Water, IoT, and the future of smart cities. | The paper outlines a plan for future work on the software solution to support full water supply network management, including integration with EPANET 2 (a water flow modeling software). | Procedia Computer Science | [1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf](../2_Papers%20to%20review/1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf) |
# | Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris | Making urban water smart: the SMART-WATER solution | 2020 | Internet of Things, LPWAN, predictive big data analytics, smart metering, machine learning | Proposes a unified framework called SMART-WATER for urban water management. It exploits state-of-the-art IoT solutions for remote telemetry and control, combined with machine learning-based processes to enhance water management and decision-making. | To propose and describe the SMART-WATER platform, a unified framework aimed at supporting water utility companies by providing innovative solutions for smart water utilization, enhancing management, and decision-making processes. | The paper does not explicitly detail future work or improvements, focusing instead on the proposed framework and its current capabilities. | Water Science & Technology | [2_MakingurbanwatersmarttheSMART-WATERsolution.pdf](../2_Papers%20to%20review/2_MakingurbanwatersmarttheSMART-WATERsolution.pdf) |
# | Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein | Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review | 2020 | Digital water meter, smart metering, machine learning, data analytic, water consumption prediction, water consumption pattern classification, leakage detection | A review summarizing the application of Machine Learning (ML) and Data Analytic (DA) techniques across the various use-cases of digital water metering, including water consumption prediction, pattern classification, and leakage detection. The paper discusses various algorithms and future challenges. | To systematically review the application of ML and DA techniques in analyzing data generated by digital water meters, categorize existing research, and discuss future research challenges and opportunities in this field. | Challenges include developing efficient ML techniques for real-time applications, managing privacy and security, integrating with smart grids and other IoT systems, and optimizing algorithms for large-scale, heterogeneous data. | Water | [2_MachineLearningandDataAnalyticTechniquesin.pdf](../2_Papers%20to%20review/2_MachineLearningandDataAnalyticTechniquesin.pdf) |
# | Sunil Sinha and Lee Sears | Collection and Compilation of Water Pipeline Field Performance Data | 2017 | Water pipeline, data collection, pipeline reliability, data standardization, database development, GIS | Presents the objectives and phases of a project aimed at collecting, compiling, and analyzing high-quality field data on pipeline reliability performance from utilities across the U.S., Canada, and Australia. It focuses on developing a Web-based, GIS-enabled national pipeline database (PIPEID). | To outline a project to collect, compile, and analyze high-quality field data on pipeline reliability performance for various materials, and to establish a standardized, GIS-enabled water pipeline database (PIPEID). | Phase II of the project, which involves model development, demonstration, benchmarking, and validation, is planned to follow the data collection and standardization of Phase I. Future work emphasizes data integration (physical, operational, environmental, social, and financial) as the key challenge. | Pipelines 2017 (Conference Proceedings) | [2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf](../2_Papers%20to%20review/2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf) |
#
# -----
