# %% [markdown]
# -----
#
# ## Data Review Summary Table
#
# | Authors | Title | Year | Data types used | Sources of the data used | Periodicity of the data (if available) | Source File Name |
# | :--- | :--- | :---: | :--- | :--- | :--- | :--- |
# | Jihong yan, Yue meng, Lei lu, Lin li | Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance | 2017 | **Industrial Big Data**, **Multisource heterogeneous data** (**Temperature signals, Vibration signals**), **unstructured/semi-structured information**, **environmental data** consideration of the spatiotemporal properties,staff behaviour, cost information, customer information, unstructured data extracted from XML files, annotations in textual data, ontology concepts, video surveillance, weather forecast data, humidity data. | **Condition monitoring and test data**, **multisource sensors**, intercommunication, and external-related information (machining equipment components). | Diverse sampling frequencies: **Vibration** (**10 kHz to 100 kHz**). | [1\_(done)(irene)Industrial\_Big\_Data\_in\_an\_Industry\_4.0\_Environment\_Challenges\_Schemes\_and\_Applications\_for\_Predictive\_Maintenance.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf) |
# | Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr | Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies | 2019 | **Corpus documents** (119 articles) covering technologies, refer to Table X, (gruped technologies). | Corpus collected from searching **EBSCOhost, Web of Science, and ScienceDirect** databases. | Survey period covered literature published up to **July 2017**. | [1\_(done)(irene)Industry4 as data-driven and technologies 2021.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)Industry4%20as%20data-driven%20and%20technologies%202021.pdf) |
# | Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza | Artificial Intelligence in manufacturing: State of the Art, Perspectives, and Future Directions | 2024 | **In-process sensing data**, **time series data**, **image data**, and **acoustic signals**. | Data derived from various **manufacturing processes** (e.g., milling tools). | Time series data. Tool wear prediction is guided to increase monotonically as **cutting cycle** increases. | [1\_(done)(irene)\_ArtificialIntelligence\_In\_manufacturing\_state\_of\_art\_futuredirections.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf) |
# | Lian Duan, Li Da Xu | Data Analytics and Industry 4.0: Survey | 2021 | **Big Data**, including **historical data**, **structured**, **semi-structured**, and **unstructured data**. CSV, JSON, XML. | The survey's own analysis data sources: **Scopus data** and **Google Scholar data**. | The analysis of trends covers the period from **2014 to 2022**. Data warehouses save **historical data**. | [1\_(done)(irene)data analytics industry4 survey 2024.pdf](../2_Papers%20to%20review/1_\(done\)\(irene\)data%20analytics%20industry4%20survey%202024.pdf) |
# | Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider | 5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models | 2021 | **Product-instance-centric information** necessary for digital continuity, real-time data, engineering data, simulation data, and operational data. | Data related to the **USAF digital thread initiative**(on the references, else not explicitly mentioned). | Not explicitly mentioned. | [1\_5-Dimension\_Cross-Industry\_Digital\_Twin\_Applications\_Model\_and\_Analysis\_of\_Digital\_Twin\_Classification\_Terms\_and\_Models.pdf](../2_Papers%20to%20review/1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf) |
# | Weiming Liu, Chen Zhang, Bin Yu, Yitong Li | A General Multi-Source Data Fusion Framework | 2019 | **Multi-source structured data**, **semi-structured data**, and **unstructured data**. Data models fused: **paper data model** and **college data model**. Unified format: **RDF** Resource  Description Framework, Textual data. | **Relational database**, **Online encyclopedias, blogs, and other Web sites**. | Not explicitly mentioned. | [1\_A General Multi-source data fusion framework.pdf](../2_Papers%20to%20review/1_A%20General%20Multi-source%20data%20fusion%20framework.pdf) |
# | Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan | A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion | 2022 | **Multi-source heterogeneous data** including **Transaction data**, **News texts**, and **Graphical indicators** (K-line, 5-day EMA, 10-day EMA). | **China Stock Market & Accounting Research (CSMAR) database**. | Data range from **2013-01-11 to 2019-11-25**. Transaction data uses features aggregated over **5 trading days**. | [1\_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf](../2_Papers%20to%20review/1_A%20graph%20neural%20network-based%20stock%20forecasting%20method%20utilizing%20multi-source%20heterogeneous%20data%20fusion.pdf) |
# | Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee | Enabling technologies and tools for digital twin | 2021 | **Raw data** (incomplete, unstructured, noisy, fuzzy, and random). Stored data types include **semi-structured and unstructured data**. Focus on the tools for data processing, check the tables included in the paper. | Requires a **real-time read-write distributed database**. Mentions using tools like **FEA software ANSYS**. | Requires **real-time** data processing and storage. | [1\_Enabling technologies and tools for digital twin.pdf](../2_Papers%20to%20review/1_Enabling%20technologies%20and%20tools%20for%20digital%20twin.pdf) |
# | Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao | FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data | 2024 | **Multi-source heterogeneous data**. Specific formats: **JSON, 210KG, CSV, and XML**. Datasets cover **Movie, Book, Flight, and Stock** data. | **Four real-world benchmark datasets** collected from various sources (**IMDb** and **wikidata**). | Framework is **adaptive to frequent data updates**; performance measured against typical update interval of **real-world data lakes**. | [1\_FusionQuery-On-demand Fusion Queries.pdf](../2_Papers%20to%20review/1_FusionQuery-On-demand%20Fusion%20Queries.pdf) |
# | Simon Kamm, Nasser Jazdi, Michael Weyrich | Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches | 2021 | **Heterogeneous data** (structural/syntactical variation and semantic variation) and **unstructured data**. Includes different types of **sensor data**, Optical, Acoustic and others. | Data isolated in separate **"data silos"**. Sources originate from **multiple sensors from different companies**, not explicitly mentioned. | Not explicitly mentioned. | [1\_Knowledge discovery in heterogeneous and unstructured data.pdf](../2_Papers%20to%20review/1_Knowledge%20discovery%20in%20heterogeneous%20and%20unstructured%20data.pdf) |
# | Theofanis P. Raptis, Andrea Passarella, Marco Conti | Data Management in Industry 4.0: State of the Art and Open Challenges | 2019 | Data characterized by **volume, variety, traffic, and criticality**. Examples include **machine energy consumption profiles**, **vibration data**, and data derived from **RFID tags**. | Data is sourced from **networked industrial environments**, **industrial sensors**, and acquired using **FPGA-based reconfigurable data acquisition systems**. | Data is collected for **archival and in real time**. Real-time data acquisition is achieved via **FPGA-based reconfigurable data acquisition systems**. | [2\_(done)(irene)Data\_Management\_in\_Industry\_4.0\_State\_of\_the\_Art\_and\_Open\_Challenges.pdf](../2_Papers%20to%20review/2_\(done\)\(irene\)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf) |
# | Sultan Baimukhanov, Hashim Ali, Adnan Yazici | Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing | 2025 | **IoT-generated information** and **IoT sensor readings**. | **IoT devices** transmitting data through **Edge and Cloud computing** environments. | Mentions capability for **real-time monitoring**. | [2\_Enhancing\_MLbased anomaly detection in data management for security on integration of iot.pdf](../2_Papers%20to%20review/2_Enhancing_MLbased%20anomaly%20detection%20in%20data%20management%20for%20security%20on%20integration%20of%20iot.pdf) |
# | Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang | A Survey on Deep Learning for Multimodal Data Fusion | 2020 | **Multimodal data**. Examples include **MRI and PET** data (images), **pose views** features, and fusion of **visual systems data** with **unannotated text**. | Sources relate to medical imaging (MRI/PET) and general visual systems. | Not explicitly mentioned. | [2\_deeplearning\_multimodal.pdf](../2_Papers%20to%20review/2_deeplearning_multimodal.pdf) |
# | Jun Wang, Xiaohan Li, Huading Jia, Tao Peng | A graph-based approach to multi-source heterogeneous information fusion in stock market | 2022 | **Multi-source heterogeneous information** consisting of **Transaction data** (financial time series) and **Stock news text data**. | **CMSAR database (China Stock Market & Accounting Research Database)**. News text data obtained via **internet crawling**. | Data ranges from **January 1, 2016, to December 31, 2020**. | [2\_graph-based multisource heterogeneous information fusion for stockmarket.pdf](../2_Papers%20to%20review/2_graph-based%20multisource%20heterogeneous%20information%20fusion%20for%20stockmarket.pdf) |
# | Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui | Multi-Source Information Fusion Based Heterogeneous Network Embedding | 2020 | **Heterogeneous network data** composed of authors, papers, and venues (nodes and relationships). Node features include **title content** (**text data**). | Two real-world network datasets: **DBLP Heterogeneous Network** and **ACM Heterogeneous Network**. | Not explicitly mentioned. | [2\_multisourceinformationfusionbasednetworkingembedding.pdf](../2_Papers%20to%20review/2_multisourceinformationfusionbasednetworkingembedding.pdf) |
# | Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli | Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction | 2021 | **Continuous heterogeneous data** (**meteorological monitoring data** and **air quality monitoring data**). Data is represented as **graph-structured data** and **time series data**. | Real dataset related to air quality in Beijing, collected from the **Harvard Dataverse** (**35 meteorological stations** and **17 air quality stations**). | Data records are collected **every hour**. Collection period: **January 1, 2017, to February 1, 2018**. | [3\_datafusion\_graphCNN.pdf](../2_Papers%20to%20review/3_datafusion_graphCNN.pdf) |
# | Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang | Multi-source Heterogeneous Data Fusion Model Based on FC-SAE | 2022 | **Multi-source heterogeneous time series data**. Includes **time series data** (daily taxi traveling data), **event text description data** (unstructured text), and **weather data**. | **Taxi traveling record data set** related to the transportation domain. | Original data is aggregated to produce **daily taxi traveling data**. Training set: **January 2013 to September 2014** , Validation set: **October to December 2014**. Test set: **January 2015 to June 2016**. | [4\_datafusion\_multisource.pdf](../2_Papers%20to%20review/4_datafusion_multisource.pdf) |
# | Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth | A Multimodal Approach for Semantic Patent Image Retrieval | 2021 | **Multimodal data** combining **Textual Features** (keywords, titles, etc.) and **Visual Features** (from patent images). | **Patent documents**. | Not explicitly mentioned. | [5\_multimodal\_patentimage.pdf](../2_Papers%20to%20review/5_multimodal_patentimage.pdf) |
# | Jeonghun Jee, Sanghyun Park, Sungjoo Lee | Potential of patent image data as technology intelligence source | 2022 | **Patent image data** (text extracted from **block diagrams**), and **Descriptive patent data**. Analysis uses a **Binary patent-to-keyword matrix**. | Data extracted from **patent documents**. Images sourced from the **Google Patent site**. | Patents grouped into four periods for **time series analysis**: **P1 (2010–2011)**, **P2 (2012–2013)**, **P3 (2014–2015)**, and **P4 (2016–2017)**. | [6\_patentimage.pdf](../2_Papers%20to%20review/6_patentimage.pdf) |
# | Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao | Research on product appearance patent spatial shape recognition for multi-image feature fusion | 2023 | **Image data** focused on **appearance design patent images**. Features analyzed include **shape features** and **texture features**. | Design patent base/documents, Smart buds patent Data base. | Smart buds patent Data base from January 2011 till December 2020 | [7\_patentimage\_spatialshapes.pdf](../2_Papers%20to%20review/7_patentimage_spatialshapes.pdf) |
# | Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang | Multi-source heterogeneous data fusion | 2018 | **Multi-source heterogeneous information**, discussion on **Multi-source domain adaptation**, **cross-media big data**, and **multimedia big data**. | Sources implicitly include generalized big data systems and reference points. | Not explicitly mentioned (Used). | [8\_Multi-source\_heterogeneous\_data\_fusion.pdf](../2_Papers%20to%20review/8_Multi-source_heterogeneous_data_fusion.pdf) |
# | Amit Mithal, Blessy Thankachan | A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management | 2025 | Water quality monitoring data (e.g., pH, dissolved oxygen, turbidity), sensor data (IoT-based monitoring), groundwater level data, real-time consumption records, transactional data (for resource trading/compliance), hydrological model outputs, and ML/DL derived data (for anomaly detection, pollution prediction). | IoT sensing infrastructure (distributed across water networks), regulatory databases, smart meters, hydrological monitoring stations, satellite data (used in some reviewed papers for context/modeling), and the Blockchain ledger itself (for secure, validated records). | Real-time or near-real-time sensor data acquisition (depending on the IoT implementation), with archival records stored on the blockchain. | [1\_(Important)A review on blockchain for water mngmnt.pdf](../2_Papers%20to%20review/1_%28Important%29A%20review%20on%20blockchain%20for%20water%20mngmnt.pdf) |
# | Nikita V. Golovastikov, Nikolay L. Kazanskiy, Svetlana N. Khonina | Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure | 2025 | Distributed and localized sensor data (Strain, Temperature, Vibration), Time-series data, Displacement/Deformation measurements, Acoustic Emission data, Multi-sensor heterogeneous data streams, and Annotated data (for damage detection/classification models). | Fiber Optic Sensors (FOS), including Fiber Bragg Grating (FBG) sensors and Distributed Fiber Optic Sensors (DFOS) embedded within civil infrastructure (bridges, tunnels, buildings). Data Acquisition Systems (DAS) and related AI processing units. | High-frequency (kHz range) distributed sensing data, allowing for real-time monitoring of dynamic structural responses (e.g., vibration analysis). | [3\_Optical Fiber-Based Structural Health Monitoring.pdf](../2_Papers%20to%20review/3_Optical%20Fiber-Based%20Structural%20Health%20Monitoring.pdf) |
# | Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu | Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0 | 2025 | Time series sensor data (e.g., vibration, temperature, pressure), Failure labels (RUL or binary), Historical run-to-failure data, Operational parameters (speed, load), and Derived features from raw sensor signals (e.g., statistical features, frequency domain features). | Industrial equipment sensors (IIoT), NASA Ames Prognostics Data Repository (specifically Turbofan Engine Degradation Simulation Dataset mentioned as a common benchmark), and specialized machinery databases. | High-frequency time-series data (for capturing machine health changes), with specific sensor rates depending on the equipment (e.g., daily snapshots for RUL, or high kHz for vibration data). | [1\_(important)Leveraging\_Directed\_Acyclic\_Graphs\_for\_Advanced\_Ensemble\_Learning\_in\_Predictive\_Maintenance\_for\_Industry\_4.0.pdf](..%2F2_Papers%20to%20review%2F1_%28important%29Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf) |
# | Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A | HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration | 2025 | Water quality sensor readings (pH, Temperature, Turbidity, Total Dissolved Solids - TDS), Historical training data (labeled for quality/contamination status), and Machine Learning model output (classification/alert status). | IoT deployment using ESP32 microcontroller interfaced with industry-grade physical sensors (pH, Temperature, Turbidity, TDS probes) deployed in water bodies. Data is transmitted to an integrated Cloud platform (e.g., Google Cloud/AWS) for storage and processing. | Real-time or near-real-time acquisition (data streamed from sensors every few seconds/minutes to the cloud platform). | [1\_(important)HydroSense\_2.0\_An\_IoT-Based\_Smart\_Water\_Quality\_Monitoring\_and\_Alert\_System\_with\_Machine\_Learning\_and\_Cloud\_Integration.pdf](../2_Papers%20to%20review/1_%28important%29HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and\_Alert\_System\_with\_Machine\_Learning\_and\_Cloud\_Integration.pdf) |
# | Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami | Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights | 2021 | High-dimensional data, Time-series data (vibration, strain, acceleration, displacement), Image/Video data (from UAVs and cameras), LiDAR/Point cloud data, Multi-sensor heterogeneous data, Spatiotemporal data, Seismic data, Acoustic data, Thermal data. | Conventional SHM sensors (accelerometers, strain gauges, fiber optics), Wireless Sensor Networks (WSNs), Internet of Things (IoT) sensors, Unmanned Aerial Vehicles (UAVs), Smartphones, External databases (e.g., climate, traffic, earthquake data). | Focuses on near real-time and online assessment; periodicity is highly diverse and often high-frequency (e.g., dynamic monitoring) depending on the Structural Health Monitoring (SHM) method. | [3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf](../2_Papers%20to%20review/3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf) |
# | Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam | Big Data analytics and IoT in Operation safety management in Under Water Management | 2020 | Operational data (e.g., water usage, flow rates), Environmental sensor data (e.g., water quality parameters), SCADA data, Big Data streams. | Internet of Things (IoT) sensors, Wireless Sensor Networks (WSN), Supervisory Control and Data Acquisition (SCADA) systems, Raspberry Pi remote monitoring devices. | The system is designed for real-time monitoring and proactive control, implying continuous or near real-time data collection. | [2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf](../2_Papers%20to%20review/2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf) |
# | N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas | A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities | 2020 | Big Data (heterogeneous data streams), Social Media data (Twitter/Tweets for crowd intelligence, text data for Natural Language Processing), Geographic Information System (GIS) data (spatial flood data, critical infrastructure locations), Historical and Real-time event data. | Multiple servers/Big Data infrastructure, Internet of Things (IoT) devices, Social media platforms (Twitter/X), Historical flood models and records, U.S. Geological Survey (USGS) for elevation and land data. | Designed to gather and analyze data during both historical and **real-time** events, implying continuous or near real-time data ingestion for situational awareness. | [2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf](../2_Papers%20to%20review/2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf) |
# | Inês Figueiredo, Paulo Esteves, Paulo Cabrita | Water wise – a digital water solution for smart cities and water management entities | 2021 | Water demand data, Operational water supply network data (e.g., flow, pressure), Energy consumption data (Water-Energy Nexus), Financial data, Sensor data (from IoT infrastructure). | IoT sensors and devices for real-time monitoring, SCADA systems (implied for operational data), external systems for energy data and financial/billing information. | Designed for **real-time monitoring** of the urban water cycle, supporting a Decision Support System (DSS). | [1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf](../2_Papers%20to%20review/1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf) |
# | Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris | Making urban water smart: the SMART-WATER solution | 2020 | Water consumption data (e.g., flow, volume), Real-time telemetry data, Smart metering data, Network state and operational data, Big Data streams (for predictive analytics). | Internet of Things (IoT) sensors and devices, Low Power Wide Area Network (LPWAN) infrastructure, Smart meters, Water utility SCADA/telemetry systems. | Designed for **remote telemetry and control**, implying continuous or near real-time data acquisition for monitoring and predictive analytics. | [2_MakingurbanwatersmarttheSMART-WATERsolution.pdf](../2_Papers%20to%20review/2_MakingurbanwatersmarttheSMART-WATERsolution.pdf) |
# | Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein | Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review | 2020 | Water consumption data (e.g., flow rate, volume), Time-series data, Customer metadata/demographics (for consumption pattern classification), Meter readings (often electronic and frequent). | Digital water meters (or intelligent water meters), Smart metering infrastructure. | High-frequency data (digital meters can frequently send consumption information electronically), suitable for **real-time** applications like leakage detection and consumption pattern analysis. | [2_MachineLearningandDataAnalyticTechniquesin.pdf](../2_Papers%20to%20review/2_MachineLearningandDataAnalyticTechniquesin.pdf) |
# | Sunil Sinha and Lee Sears | Collection and Compilation of Water Pipeline Field Performance Data | 2017 | Pipeline Reliability Performance Data, Infrastructure Inventory Data (material type: cast iron, ductile iron, concrete, steel, PVC, AC, etc.), Physical Data, Operational Data, Environmental Data, Social Data, Financial Data, Condition Assessment Data. | U.S. Bureau of Reclamation (USBR), U.S., Canadian, and Australian Water Utilities, Web-based, GIS-enabled national pipeline database (PIPEID), Various data collection projects (Phase I). | The data collected is largely **static** (infrastructure inventory) and **historical** (reliability performance), with a goal of future integration to support dynamic modeling. | [2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf](../2_Papers%20to%20review/2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf) |
