# %%
import pandas as pd
from itables import show

data = [
    {"Authors": "Jihong yan, Yue meng, Lei lu, Lin li", "Title": "Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance", "Year": 2017, "Keywords": "Industrial Big Data, Predictive Maintenance, Multisource heterogeneous data, Structuralization and characterization, Multiple invisible factors", "General Idea (Short and Brief)": "(Cites relevant papers useful for our basis) Reviews the challenges, schemes, and applications of Industrial Big Data within the Industry 4.0 environment, with a focus on Predictive Maintenance.", "Objective of the Article": "To present a summary of the challenges, schemes, and applications of Industrial Big Data for Predictive Maintenance in the context of Industry 4.0.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "IEEE Access", "Source File Name": "1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf"},
    {"Authors": "Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr", "Title": "Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies", "Year": 2019, "Keywords": "Digitization, Technology, Industry 4.0", "General Idea (Short and Brief)": "(Cites relevant papers useful for our basis) A systematic review defining Industry 4.0 as a data-driven paradigm and identifying 111 associated technologies, grouped by their function (generation, transmission, processing, application).", "Objective of the Article": "To explain the complex nature of Industry 4.0 by developing a framework that groups and links its identified technologies based on their data functions.", "Future Work or Improvements": "Intensify research into Data Application technologies. Explore relationships between technologies using Social Network Analysis.", "Journal/Publication": "Journal of Manufacturing Technology Management", "Source File Name": "1_(done)(irene)Industry4 as data-driven and technologies 2021.pdf"},
    {"Authors": "Lian Duan, Li Da Xu", "Title": "Data Analytics and Industry 4.0: Survey", "Year": 2021, "Keywords": "Industry 4.0, Data Analytics, Big Data, Cloud computing, Internet of things, Cyber-physical Systems (CPSs), Manufacturing, Digital Twin, 5G, Blockchain", "General Idea (Short and Brief)": "(Cites relevant papers useful for our basis) Discusses the necessity and benefits of merging Industry 4.0 and Data Analytics (routine operations meeting smart decisions) and reviews existing research trends in this intersection.", "Objective of the Article": "To study the basic concepts, benefits, and interaction between Industry 4.0 and Data Analytics, and conduct a systematic review to understand the research focus and trend.", "Future Work or Improvements": "Continue joint research on different intersections with different components (industry sectors, CPSs, and analytic methods).", "Journal/Publication": "Information Systems Frontiers", "Source File Name": "1_(done)(irene)data analytics industry4 survey 2024.pdf"},
    {"Authors": "Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider", "Title": "5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models", "Year": 2021, "Keywords": "Applications, classifications, cross-industry, description, Digital Twin, model", "General Idea (Short and Brief)": "Proposes a structured model for Digital Twin applications based on a sequence of five steps: Scope Physical, Features of Physical, Data communication, Scope virtual, Value output.", "Objective of the Article": "To analyze Digital Twin classification terms and models, and propose a new structured framework (the 5-dimension model implemented from Grieves) for DT applications.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "IEEE Access", "Source File Name": "1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf"},
    {"Authors": "Weiming Liu, Chen Zhang, Bin Yu, Yitong Li", "Title": "A General Multi-Source Data Fusion Framework", "Year": 2019, "Keywords": "Multi-source data, Data fusion, RDF  (Resource Description Frame work), Data matching, Conflict resolution", "General Idea (Short and Brief)": "Proposes a general four-layer framework based on an improved RDF  (Resource Description Framework)  to integrate heterogeneous multi-source data and resolve heterogeneity and semantic conflicts.", "Objective of the Article": "To propose a general four-layer framework to solve heterogeneity and semantic conflicts in multi-source data fusion and improve the original RDF-based data fusion framework.", "Future Work or Improvements": "Will work on conflict resolution methods for multi-language application scenarios in follow-up works.", "Journal/Publication": "Association for Computing Machinery (ACM)", "Source File Name": "1_A General Multi-source data fusion framework.pdf"},
    {"Authors": "Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan", "Title": "A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion", "Year": 2022, "Keywords": "Stock prediction, Graph data, Graph neural network, Multi-source data", "General Idea (Short and Brief)": "Proposes a graph-based model utilizing GNN and attention mechanisms to fuse heterogeneous data (transaction metrics and financial news text obtained via web crawling) for predicting stock market fluctuations.", "Objective of the Article": "To achieve classification prediction of stock market fluctuations by employing a graph-based approach to fuse multi-source heterogeneous information.", "Future Work or Improvements": "Expand to multi-attention mechanisms. further study the interaction mechanism between multi-source heterogeneous data.", "Journal/Publication": "Multimedia Tools and Applications", "Source File Name": "1_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf"},
    {"Authors": "Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee", "Title": "Enabling technologies and tools for digital twin", "Year": 2021, "Keywords": "Digital twin, Five-dimension model, Enabling technologies, Enabling tools", "General Idea (Short and Brief)": "A review detailing the architecture, components, and tools required to implement the Digital Twin concept, placing it within the context of CPS and Industry 4.0.", "Objective of the Article": "To review and analyze the technologies and tools that enable the Digital Twin, including its architecture and correlation with CPS and Industry 4.0/Smart Manufacturing.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "[ScienceDirect] Journal of Manufacturing Systems", "Source File Name": "1_Enabling technologies and tools for digital twin.pdf"},
    {"Authors": "Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao", "Title": "FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data", "Year": 2024, "Keywords": "(Extracted from text) On-demand Fusion Queries (OD-FQ), Multi-source Heterogeneous Data, Between-source Conflicts, Data Veracity, Source Trustworthiness", "General Idea (Short and Brief)": "Presents FusionQuery, an efficient framework using knowledge graph matching and an iterative EM-style algorithm to perform real-time data fusion and resolve conflicts only on query-related heterogeneous data.", "Objective of the Article": "To address the limitations of batch data fusion by proposing and evaluating an effective and scalable system for handling on-demand fusion queries over heterogeneous multi-source data, examples on how LLM's can fact check information more efficiently.", "Future Work or Improvements": "Plan to further enhance the effectiveness of the on-demand fusion query.", "Journal/Publication": "PVLDB (Proceedings of the VLDB Endowment)", "Source File Name": "1_FusionQuery-On-demand Fusion Queries.pdf"},
    {"Authors": "Simon Kamm, Nasser Jazdi, Michael Weyrich", "Title": "Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches", "Year": 2021, "Keywords": "Heterogeneous Data, Industry 4.0, Internet of Things, Knowledge Discovery, Machine Learning, Semantic Data Integration, Unstructured Data", "General Idea (Short and Brief)": "Discusses challenges for Knowledge Discovery (KDD) in Industry 4.0 due to the increasing volume and heterogeneity of data, which often results in separated \"data silos\".", "Objective of the Article": "To identify and analyze the challenges and necessary approaches for Knowledge Discovery in Industry 4.0 systems dealing with heterogeneous and unstructured data.", "Future Work or Improvements": "Detailed concretization and comparative analysis of existing approaches. This work will specifically target industrial automation systems operating under challenging environmental conditions, such as strict timing requirements or distributed partial processes.", "Journal/Publication": "Procedia CIRP", "Source File Name": "1_Knowledge discovery in heterogeneous and unstructured data.pdf"},
    {"Authors": "Theofanis P. Raptis, Andrea Passarella, Marco Conti", "Title": "Data Management in Industry 4.0: State of the Art and Open Challenges", "Year": 2019, "Keywords": "Data management, industrial networks, manufacturing, Industry 4.0", "General Idea (Short and Brief)": "(Cites relevant papers useful for our basis) A survey reviewing data management issues (2015-2018) in networked industrial environments (Industry 4.0), classifying relevant technologies and services.", "Objective of the Article": "To survey the literature and identify open challenges for data management in the intersection of industrial automation and communication/networking fields.", "Future Work or Improvements": "Open challenges include: Energy efficient data delivery; Data distribution in local and mobile clouds; Distributed, real-time data security; and Convergence between communications and industrial automation.", "Journal/Publication": "IEEE Access", "Source File Name": "2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf"},
    {"Authors": "Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang", "Title": "A Survey on Deep Learning for Multimodal Data Fusion", "Year": 2020, "Keywords": "(Extracted from text) Deep Learning (DL), Multimodal Data Fusion, DBN, SAE, CNN, RNN, Semantic Fusion Strategies", "General Idea (Short and Brief)": "Surveys Deep Learning models designed for multimodal data fusion, categorizing approaches based on architectures like Deep Belief Networks (DBN) and Recurrent Neural Networks (RNN) among others.", "Objective of the Article": "To provide an overview and summarize deep learning models developed for multimodal data fusion, built on current representative DL architectures.", "Future Work or Improvements": "New DL models that take semantic relationships into consideration are urgently needed. Suggests combining deep learning with semantic fusion strategies.", "Journal/Publication": "Neural Computation", "Source File Name": "2_deeplearning_multimodal.pdf"},
    {"Authors": "Jun Wang, Xiaohan Li, Huading Jia, Tao Peng", "Title": "A graph-based approach to multi-source heterogeneous information fusion in stock market", "Year": 2022, "Keywords": "Graph fusion, Heterogeneous information/data, Relational dimension, Multi-attention graph neural network, Stock market price fluctuation/prediction, Complex network, Information spillover", "General Idea (Short and Brief)": "Proposes a graph fusion and embedding method using a multi-attention GNN to incorporate multi-source heterogeneous data and relational information for predicting stock market volatility.", "Objective of the Article": "To establish a graph fusion and embedding method using relational dimension information for fusing heterogeneous data, and construct a GNN to mine implied semantics for stock price prediction.", "Future Work or Improvements": "Expand node features (e.g., trading data derivative index, graphical data) and study the interaction mechanism of heterogeneous data. Explore building a public opinion monitoring function for securities market regulation.", "Journal/Publication": "PLoS ONE", "Source File Name": "2_graph-based multisource heterogeneous information fusion for stockmarket.pdf"},
    {"Authors": "Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui", "Title": "Multi-Source Information Fusion Based Heterogeneous Network Embedding", "Year": 2020, "Keywords": "Heterogeneous Network Embedding, Multi-Source Information Fusion, Representation Learning, Joint Learning", "General Idea (Short and Brief)": "Proposes MIFHNE, a generic approach to enhance network embedding by integrating rich multi-source information (structural, semantic, attribute, and label data) in Heterogeneous Information Networks (HINs).", "Objective of the Article": "To propose and validate the MIFHNE approach, demonstrating the importance of multi-source information fusion for network embedding in HINs.", "Future Work or Improvements": "Future work is presented in Section 6. (will focus on the possibility of the attribute information of node being multimodal, basis for designing an efficient embedding method for heterogeneous network)", "Journal/Publication": "[ScienceDirect] Information Sciences", "Source File Name": "2_multisourceinformationfusionbasednetworkingembedding.pdf"},
    {"Authors": "Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli", "Title": "Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction", "Year": 2021, "Keywords": "Heterogeneous data sources, Data fusion, Radial Basis Functions (RBF), Deep Learning, Graph Convolutional Networks (GCN)", "General Idea (Short and Brief)": "Describes a data fusion pipeline where raw heterogeneous data is preprocessed/fused (e.g., via RBF function), then modeled using various ML Model (GCN/GCNN/STGCN) architectures for prediction.", "Objective of the Article": "To construct a pipeline for heterogeneous data fusion and modeling using graph convolutional network architectures dedicated to AirQuality prediction.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "Journal of King Saud University - Computer and Information Sciences", "Source File Name": "3_datafusion_graphCNN.pdf"},
    {"Authors": "Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang", "Title": "Multi-source Heterogeneous Data Fusion Model Based on FC-SAE", "Year": 2022, "Keywords": "Multi-source heterogeneous, Data fusion, Deep learning, SAE, FC", "General Idea (Short and Brief)": "Proposes the FC-SAE model (Fully Connected Sparse Autoencoder) as a fusion mechanism to integrate time-series data and text data for enhanced forecasting accuracy.", "Objective of the Article": "To propose an FC-SAE based multi-source heterogeneous data fusion model that breaks the structural barrier between time series data and text data.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "Journal of Internet Technology", "Source File Name": "4_datafusion_multisource.pdf"},
    {"Authors": "Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth", "Title": "A Multimodal Approach for Semantic Patent Image Retrieval", "Year": 2021, "Keywords": "Patent Image Similarity Search, Deep Learning, Mulitmodal Feature Representations, Scene Text Spotting", "General Idea (Short and Brief)": "Presents a multimodal retrieval system for patent images that extracts and fuses both textual features (from figure descriptions) and visual features (from images) using score re-ranking.", "Objective of the Article": "To evaluate and improve the relevance of patent retrieval results using the multimodal feature fusion derived from patent images and their associated textual descriptions.", "Future Work or Improvements": "Plan to exploit further information in images (e.g., non-numeric image text). Intend to incorporate multimodal information in an end-to-end network or joint framework.", "Journal/Publication": "PatentSemTech", "Source File Name": "5_multimodal_patentimage.pdf"},
    {"Authors": "Jeonghun Jee, Sanghyun Park, Sungjoo Lee", "Title": "Potential of patent image data as technology intelligence source", "Year": 2022, "Keywords": "Patent analysis, Image data, Technology intelligence, Product structure, Network analysis, Block diagrams", "General Idea (Short and Brief)": "Investigates the potential of texts extracted specifically from patent block diagrams (images) as a crucial source of technology intelligence for structural analysis.", "Objective of the Article": "To investigate the potential of patent image data, particularly text from block diagrams, to be used as a source of technology intelligence.", "Future Work or Improvements": "Requires a more elaborated method for identifying meaningful terms using n-grams or pre-defined dictionaries. Future study needed to customize the approach to various other types of patent drawings. Investigate the potential value of combining subject-action-object (SAO) analysis with image analysis.", "Journal/Publication": "[ScienceDirect] Journal of Informetrics", "Source File Name": "6_patentimage.pdf"},
    {"Authors": "Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao", "Title": "Research on product appearance patent spatial shape recognition for multi-image feature fusion", "Year": 2023, "Keywords": "Design Patent Search System, Spatial Shape Recognition, Multi-image fusion, Image Segmentation, Contour Description", "General Idea (Short and Brief)": "Describes the system design and user interface functionality for a design patent search system specializing in spatial shape recognition, which relies on analyzing and fusing multiple images/views.", "Objective of the Article": "To demonstrate a system and methodology for retrieving design patents based on spatial shape recognition using multi-image fusion.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "[Springer] Multimedia Tools and Applications", "Source File Name": "7_patentimage_spatialshapes.pdf"},
    {"Authors": "Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang", "Title": "Multi-source heterogeneous data fusion", "Year": 2018, "Keywords": "Big data,Heterogeneous data, Data fusion,Heterogeneous data fusion, Deep learning", "General Idea (Short and Brief)": "Overview of the problems, challenges, and technologies associated with multi-source data fusion in the context of Big Data, referencing methodologies like Ensemble Learning and Deep Learning approaches.", "Objective of the Article": "To overview problems and challenges associated with Big Data fusion, particularly emphasizing Deep Learning models for fusing heterogeneous sensor data.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "IEEE Xplore", "Source File Name": "8_Multi-source_heterogeneous_data_fusion.pdf"},
    {"Authors": "Sultan Baimukhanov, Hashim Ali, Adnan Yazici", "Title": "Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing", "Year": 2025, "Keywords": "IoT-Cloud Interaction, Data management in IoT, IoT security vulnerabilities, Anomaly detection, Explainable AI", "General Idea (Short and Brief)": "Proposes a system (SSPA) integrating Machine Learning (ML), IoT, Cloud Computing (CC), and Edge Computing (EC) to enhance anomaly detection specifically for security and data management in IoT environments. The system uses the iForest algorithm for anomaly detection.", "Objective of the Article": "To explore the potential of integrating ML, IoT, CC, and EC to improve anomaly detection in data management and substantiate the practical applicability and viability of the proposed solution.", "Future Work or Improvements": "Not explicitly mentioned.", "Journal/Publication": "[ScienceDirect] Expert Systems With Applications", "Source File Name": "2_Enhancing_MLbased anomaly detection in data management for security on integration of iot.pdf"},
    {"Authors": "Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza", "Title": "Artificial Intelligence in manufacturing: State of the art, perspectives, and future directions", "Year": 2024, "Keywords": "Artificial intelligence, Smart manufacturing, Machine learning", "General Idea (Short and Brief)": "Reviews state-of-the-art AI applications (model-based & data-driven) across the manufacturing lifecycle (design, process, quality, assembly) to guide the realization of smart manufacturing (well updated and analyzing current trends).", "Objective of the Article": "To present advances in AI in manufacturing with an integrated view of system, process, quality, and (dis)assembly, map AI technologies to manufacturing tasks, and outline emerging challenges and future directions.", "Future Work or Improvements": "Expand on unsupervised learning, integrating physics with AI, developing causal AI, adopting next-generation Generative AI and Generalist AI models (LLMs), researching AI-specific hardware, and focusing on real-life AI introduction (trustworthiness).", "Journal/Publication": "[ScienceDirect] CIRP Annals - Manufacturing Technology", "Source File Name": "1_(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf"},
    {"Authors": "Amit Mithal, Blessy Thankachan","Title": "A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management","Year": 2025,"Keywords": "Blockchain Technology, Machine Learning (ML), Deep Learning (DL), Groundwater Conservation, Wastewater Management, Data Integrity, Anomaly Detection, Resource Optimization, Regulatory Compliance","General Idea (Short and Brief)": "A systematic review (2019-2025) of 97 peer-reviewed articles analyzing the convergence of **Blockchain, Machine Learning (ML), and Deep Learning (DL)** to enhance sustainability, maintain data integrity, and optimize resource utilization in the water sector.","Objective of the Article": "To systematically analyze recent technological advances, evaluate performance improvements achieved through Blockchain/AI integration, and identify critical research gaps and future directions for sustainable water resource management.","Future Work or Improvements": "The abstract confirms the identification of **research gaps and future directions** (e.g., improved data validation, resource optimization, transparency).","Journal/Publication": "Environmental Management","Source File Name": "1_(Important)A review on blockchain for water mngmnt.pdf"},
    {"Authors": "Nikita V. Golovastikov, Nikolay L. Kazanskiy, and Svetlana N. Khonina","Title": "Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure","Year": 2025,"Keywords": "Optical Fiber Sensors (OFS), Structural Health Monitoring (SHM), Dams, Pipelines, Distributed Acoustic Sensing (DAS), Water Management, Artificial Intelligence (AI)","General Idea (Short and Brief)": "A comprehensive review of Optical Fiber Sensors (OFS) for Structural Health Monitoring (SHM), specifically detailing their application in monitoring the structural integrity, seepage, leakage, and dynamic conditions of **dams, water management infrastructure, and long-distance pipelines**.","Objective of the Article": "To review the latest advancements, applications, and integration of OFS and AI/Machine Learning techniques for SHM in civil and urban infrastructure, including critical water assets.","Future Work or Improvements": "Develop more dynamic Digital Twin models for real-time monitoring. Establish standardization of test procedures and calibration for OFS.","Journal/Publication": "Photonics","Source File Name": "3_Optical Fiber-Based Structural Health Monitoring.pdf"},
    {"Authors": "Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu","Title": "Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0","Year": 2025,"Keywords": "Directed Acyclic Graphs (DAGs), Ensemble Learning, Predictive Maintenance, Industry 4.0, Machine Learning, Failure Prediction","General Idea (Short and Brief)": "Proposes a novel approach using Directed Acyclic Graphs (DAGs) to ensemble multiple machine learning models, enabling more robust and accurate failure predictions for Predictive Maintenance in Industry 4.0.","Objective of the Article": "To propose a novel approach using Directed Acyclic Graphs (DAGs) to ensemble multiple machine learning models, enabling more robust and accurate failure predictions.","Future Work or Improvements": "Not explicitly mentioned in the abstract.","Journal/Publication": "2025 International Conference on Next Generation Communication & Information Processing (INCIP)","Source File Name": "1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf"},
    {"Authors": "Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A","Title": "HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration","Year": 2025,"Keywords": "IoT, Water Quality Monitoring, Machine Learning, Cloud Integration, ESP32, Real-time Alerts, Public Health","General Idea (Short and Brief)": "Presents HydroSense 2.0, an intelligent water quality monitoring system using **IoT sensors (pH, temperature, turbidity, TDS)**, an ESP32 microcontroller, and machine learning models for real-time surveillance and automated alerts.","Objective of the Article": "To develop and deploy a comprehensive, real-time, automated water quality surveillance system (HydroSense 2.0) integrated with cloud computing and machine learning to address public health and safety concerns.","Future Work or Improvements": "Not explicitly mentioned in the abstract.","Journal/Publication": "2025 International Conference on Computing Technologies & Data Communication (ICCTDC)","Source File Name": "1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf"},
    {"Authors": "Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami", "Title": "Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights", "Year": 2021, "Keywords": "Structural health monitoring, machine learning, internet of things, big data, emerging technologies", "General Idea (Short and Brief)": "A review clarifying and summarizing the Machine Learning (ML) pipelines and frontiers in modern Structural Health Monitoring (SHM) systems, with a focus on emerging technologies like IoT, Big Data, UAVs, AR/VR, and Digital Twins.", "Objective of the Article": "To clarify and review the ML frontiers involved in modern SHM systems, detailing ML pipelines, tools, and algorithms, and exploring the connection to next-generation technologies and data science prospects for SHM.", "Future Work or Improvements": "The article examines current and future challenges and open research issues in the SHM-ML conjunction and offers an outlook on the future of monitoring civil infrastructure integrity.", "Journal/Publication": "Structural Health Monitoring", "Source File Name": "3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf"},
    {"Authors": "Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam", "Title": "Big Data analytics and IoT in Operation safety management in Under Water Management", "Year": 2020, "Keywords": "Big Data Analytics, Internet of Things, Water management, Sensors, WSN", "General Idea (Short and Brief)": "The paper proposes a Supervisory Control and Data Acquisition (SCADA) approach using IoT and Big Data Analytics for sustainable smart water management. Experimental results demonstrate that this implementation proactively controls water usage and achieves higher levels of sustainable water supply.", "Objective of the Article": "To propose a Mathematical model and demonstrate the Supervisory Control and Data Acquisition (SCADA) method for smart water management using IoT and Big Data Analytics, including remote environmental monitoring using Raspberry Pi and Python.", "Future Work or Improvements": "The authors recommend developing more models using Big Data and IoT for long-term evaluation and scheduling of water distribution networks, performing multi-periodic leakage stream analysis, and expanding performance analyses to include natural and man-made disasters (e.g., earthquakes, thefts, and terrorism).", "Journal/Publication": "Computer Communications", "Source File Name": "2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf"},
    {"Authors": "N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas", "Title": "A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities", "Year": 2020, "Keywords": "Internet of things, Flood analytics information system, Machine learning, Big Data, Flood situational awareness", "General Idea (Short and Brief)": "Presents a national-scale Flood Analytics Information System (FAIS) as a Python Web application. This system gathers Big Data from multiple sources, integrates crowd intelligence, Machine Learning (ML), and Natural Language Processing (NLP) of tweets to provide flood warnings and improve situational awareness for flood risk management.", "Objective of the Article": "To develop and demonstrate the capabilities of the Flood Analytics Information System (FAIS) to assess flooding impacts during historical and real-time events by leveraging IoT, Big Data, ML, and crowd-sourced intelligence.", "Future Work or Improvements": "The paper suggests expanding the system's spatial coverage (beyond The Carolinas) and integrating more detailed infrastructure and socio-economic data for improved vulnerability assessments.", "Journal/Publication": "Environmental Modelling and Software", "Source File Name": "2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf"},
    {"Authors": "Inês Figueiredo, Paulo Esteves, Paulo Cabrita", "Title": "Water wise – a digital water solution for smart cities and water management entities", "Year": 2021, "Keywords": "Digital water, Smart cities, Water management, Water-Energy Nexus, IoT, Decision support system", "General Idea (Short and Brief)": "Presents the 'Water Wise System' (W2S), a digital water solution developed to efficiently manage the urban water cycle. The system utilizes real-time monitoring, a decision support system, and addresses the water-energy nexus for smart cities.", "Objective of the Article": "To present a preliminary study of the architecture and software solution for the Water Wise System (W2S), focusing on water management challenges, available technology, Digital Water, IoT, and the future of smart cities.", "Future Work or Improvements": "The paper outlines a plan for future work on the software solution to support full water supply network management, including integration with EPANET 2 (a water flow modeling software).", "Journal/Publication": "Procedia Computer Science", "Source File Name": "1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf"},
    {"Authors": "Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris", "Title": "Making urban water smart: the SMART-WATER solution", "Year": 2020, "Keywords": "Internet of Things, LPWAN, predictive big data analytics, smart metering, machine learning", "General Idea (Short and Brief)": "Proposes a unified framework called SMART-WATER for urban water management. It exploits state-of-the-art IoT solutions for remote telemetry and control, combined with machine learning-based processes to enhance water management and decision-making.", "Objective of the Article": "To propose and describe the SMART-WATER platform, a unified framework aimed at supporting water utility companies by providing innovative solutions for smart water utilization, enhancing management, and decision-making processes.", "Future Work or Improvements": "The paper does not explicitly detail future work or improvements, focusing instead on the proposed framework and its current capabilities.", "Journal/Publication": "Water Science & Technology", "Source File Name": "2_MakingurbanwatersmarttheSMART-WATERsolution.pdf"},
    {"Authors": "Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein", "Title": "Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review", "Year": 2020, "Keywords": "Digital water meter, smart metering, machine learning, data analytic, water consumption prediction, water consumption pattern classification, leakage detection", "General Idea (Short and Brief)": "A review summarizing the application of Machine Learning (ML) and Data Analytic (DA) techniques across the various use-cases of digital water metering, including water consumption prediction, pattern classification, and leakage detection. The paper discusses various algorithms and future challenges.", "Objective of the Article": "To systematically review the application of ML and DA techniques in analyzing data generated by digital water meters, categorize existing research, and discuss future research challenges and opportunities in this field.", "Future Work or Improvements": "Challenges include developing efficient ML techniques for real-time applications, managing privacy and security, integrating with smart grids and other IoT systems, and optimizing algorithms for large-scale, heterogeneous data.", "Journal/Publication": "Water", "Source File Name": "2_MachineLearningandDataAnalyticTechniquesin.pdf"},
    {"Authors": "Sunil Sinha and Lee Sears", "Title": "Collection and Compilation of Water Pipeline Field Performance Data", "Year": 2017, "Keywords": "Water pipeline, data collection, pipeline reliability, data standardization, database development, GIS", "General Idea (Short and Brief)": "Presents the objectives and phases of a project aimed at collecting, compiling, and analyzing high-quality field data on pipeline reliability performance from utilities across the U.S., Canada, and Australia. It focuses on developing a Web-based, GIS-enabled national pipeline database (PIPEID).", "Objective of the Article": "To outline a project to collect, compile, and analyze high-quality field data on pipeline reliability performance for various materials, and to establish a standardized, GIS-enabled water pipeline database (PIPEID).", "Future Work or Improvements": "Phase II of the project, which involves model development, demonstration, benchmarking, and validation, is planned to follow the data collection and standardization of Phase I. Future work emphasizes data integration (physical, operational, environmental, social, and financial) as the key challenge.", "Journal/Publication": "Pipelines 2017 (Conference Proceedings)", "Source File Name": "2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf"},

]

# 2. Create the DataFrame
df = pd.DataFrame(data)

# 3. Render the interactive table (Sorting and filtering are enabled by these parameters)
show(df, 
     lengthMenu=[5, 10, 25], 
     classes=["display", "cell-border"], 
     caption="Literature Review (Interactive and Filterable)",
     dom="<lfipt>",
     init_js=[
        """
        // Add text input for filtering below each column header
        var api = this.api();
        api.columns().every(function() {
            var column = this;
            var input = $('<input type="text" placeholder="Filter..." />')
                .appendTo($(column.footer()).empty())
                .on('keyup change clear', function() {
                    if (column.search() !== this.value) {
                        column.search(this.value).draw();
                    }
                });
            // This is needed because iTables puts the table in the thead/tfoot when rendering
            $(input).parent().parent().parent().addClass("filter_row");
        });
        """
     ]
)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ee3a1c37_e7d3_49e6_ba77_fe9292b49349"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
from IPython.display import HTML, display

content_html = """
<div style="width: 100%; height: 600px; overflow: auto; border: 2px solid #007bff; padding: 5px;">
<style>
    /* Ensures the table is very wide (180%) to force horizontal scrolling */
    table { width: 180%; border-collapse: collapse; font-size: 14px; }
    
    /* Border color set to #bbb (grayish) */
    th, td { border: 1px solid #bbb; padding: 8px; text-align: left; vertical-align: top; } 
    
    /* Header background, bold, and text color set to black */
    th { background-color: #f2f2f2; font-weight: bold; color: black; }
    
    /* Style the wide columns (General Idea, Objective, Future Work) to be more readable */
    td:nth-child(5), td:nth-child(6), td:nth-child(7) { min-width: 200px; }
    
    /* Set a minimum width for the new Journal/Publication column */
    td:nth-child(8) { min-width: 150px; }

    /* MODIFIED: Force the Source File Name column to break words and be narrower */
    td:nth-child(9) { 
        min-width: 100px; 
        word-break: break-all; 
    }
</style>

    <table>
        <thead>
            <tr>
                <th>Authors</th>
                <th>Title</th>
                <th>Year</th>
                <th>Keywords</th>
                <th>General Idea (Short and Brief)</th>
                <th>Objective of the Article</th>
                <th>Future Work or Improvements</th>
                <th>Journal/Publication</th> 
                <th>Source File Name</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td> Jihong yan, Yue meng, Lei lu, Lin li </td>
                <td> Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance </td>
                <td> 2017 </td>
                <td> Industrial Big Data, Predictive Maintenance, Multisource heterogeneous data, Structuralization and characterization, Multiple invisible factors </td>
                <td> (Cites relevant papers useful for our basis) Reviews the challenges, schemes, and applications of <strong>Industrial Big Data</strong> within the Industry 4.0 environment, with a focus on <strong>Predictive Maintenance</strong>. </td>
                <td> To present a summary of the challenges, schemes, and applications of Industrial Big Data for Predictive Maintenance in the context of Industry 4.0. </td>
                <td> Not explicitly mentioned. </td>
                <td> IEEE Access </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf" target="_blank">1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf</a></td>
            </tr>
            <tr>
                <td>  Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr  </td>
                <td> Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies </td>
                <td> 2019 </td>
                <td> Digitization, Technology, Industry 4.0 </td>
                <td> (Cites relevant papers useful for our basis) A systematic review defining Industry 4.0 as a <strong>data-driven paradigm</strong> and identifying 111 associated technologies, grouped by their function (generation, transmission, processing, application). </td>
                <td> To explain the complex nature of Industry 4.0 by developing a framework that groups and links its identified technologies based on their data functions. </td>
                <td> <strong>Intensify research into Data Application technologies</strong>. <strong>Explore relationships between technologies using Social Network Analysis</strong>. </td>
                <td> Journal of Manufacturing Technology Management </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)Industry4%20as%20data-driven%20and%20technologies%202021.pdf" target="_blank">1_(done)(irene)Industry4 as data-driven and technologies 2021.pdf</a></td>
            </tr>
            <tr>
                <td> Lian Duan, Li Da Xu </td>
                <td> Data Analytics and Industry 4.0: Survey </td>
                <td> 2021 </td>
                <td> Industry 4.0, Data Analytics, Big Data, Cloud computing, Internet of things, Cyber-physical Systems (CPSs), Manufacturing, Digital Twin, 5G, Blockchain </td>
                <td> (Cites relevant papers useful for our basis) Discusses the necessity and benefits of merging <strong>Industry 4.0 and Data Analytics</strong> (routine operations meeting smart decisions) and reviews existing research trends in this intersection. </td>
                <td> To study the basic concepts, benefits, and interaction between Industry 4.0 and Data Analytics, and conduct a systematic review to understand the research focus and trend. </td>
                <td> Continue joint research on different intersections with different components (industry sectors, CPSs, and analytic methods). </td>
                <td> Information Systems Frontiers </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)data%20analytics%20industry4%20survey%202024.pdf" target="_blank">1_(done)(irene)data analytics industry4 survey 2024.pdf</a></td>
            </tr>
            <tr>
                <td> Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider </td>
                <td> 5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models </td>
                <td> 2021 </td>
                <td> Applications, classifications, cross-industry, description, Digital Twin, model </td>
                <td> Proposes a structured model for Digital Twin applications based on a sequence of five steps: Scope Physical, Features of Physical, Data communication, Scope virtual, Value output. </td>
                <td> To analyze Digital Twin classification terms and models, and propose a new structured framework (the 5-dimension model implemented from Grieves) for DT applications. </td>
                <td> Not explicitly mentioned. </td>
                <td> IEEE Access </td>
                <td><a href="../2_Papers%20to%20review/1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf" target="_blank">1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf</a></td>
            </tr>
            <tr>
                <td> Weiming Liu, Chen Zhang, Bin Yu, Yitong Li </td>
                <td> A General Multi-Source Data Fusion Framework </td>
                <td> 2019 </td>
                <td> Multi-source data, Data fusion, RDF (Resource Description Frame work), Data matching, Conflict resolution </td>
                <td> Proposes a general <strong>four-layer framework</strong> based on an improved <strong>RDF (Resource Description Framework) </strong> to integrate heterogeneous multi-source data and resolve heterogeneity and semantic conflicts. </td>
                <td> To propose a general four-layer framework to solve heterogeneity and semantic conflicts in multi-source data fusion and improve the original RDF-based data fusion framework. </td>
                <td> Will work on <strong>conflict resolution methods for multi-language application scenarios</strong> in follow-up works. </td>
                <td> Association for Computing Machinery (ACM) </td>
                <td><a href="../2_Papers%20to%20review/1_A%20General%20Multi-source%20data%20fusion%20framework.pdf" target="_blank">1_A General Multi-source data fusion framework.pdf</a></td>
            </tr>
            <tr>
                <td> Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan </td>
                <td> A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion </td>
                <td> 2022 </td>
                <td> Stock prediction, Graph data, Graph neural network, Multi-source data </td>
                <td> Proposes a graph-based model utilizing GNN and attention mechanisms to fuse heterogeneous data (transaction metrics and financial news text obtained via web crawling) for predicting stock market fluctuations. </td>
                <td> To achieve classification prediction of stock market fluctuations by employing a graph-based approach to fuse multi-source heterogeneous information. </td>
                <td> <strong>Expand to multi-attention mechanisms</strong>, further study the interaction mechanism between multi-source heterogeneous data. </td>
                <td> Multimedia Tools and Applications </td>
                <td><a href="../2_Papers%20to%20review/1_A%20graph%20neural%20network-based%20stock%20forecasting%20method%20utilizing%20multi-source%20heterogeneous%20data%20fusion.pdf" target="_blank">1_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf</a></td>
            </tr>
            <tr>
                <td> Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee </td>
                <td> Enabling technologies and tools for digital twin </td>
                <td> 2021 </td>
                <td> Digital twin, Five-dimension model, Enabling technologies, Enabling tools </td>
                <td> A review detailing the architecture, components, and <strong>tools required to implement the Digital Twin</strong> concept, placing it within the context of CPS and Industry 4.0. </td>
                <td> To review and analyze the technologies and tools that enable the Digital Twin, including its architecture and correlation with CPS and Industry 4.0/Smart Manufacturing. </td>
                <td> Not explicitly mentioned. </td>
                <td> [ScienceDirect] Journal of Manufacturing Systems </td>
                <td><a href="../2_Papers%20to%20review/1_Enabling%20technologies%20and%20tools%20for%20digital%20twin.pdf" target="_blank">1_Enabling technologies and tools for digital twin.pdf</a></td>
            </tr>
            <tr>
                <td> Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao </td>
                <td> FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data </td>
                <td> 2024 </td>
                <td> (Extracted from text) On-demand Fusion Queries (OD-FQ), Multi-source Heterogeneous Data, Between-source Conflicts, Data Veracity, Source Trustworthiness </td>
                <td> Presents <strong>FusionQuery</strong>, an efficient framework using knowledge graph matching and an iterative EM-style algorithm to perform <strong>real-time data fusion</strong> and resolve conflicts only on query-related heterogeneous data. </td>
                <td> To address the limitations of batch data fusion by proposing and evaluating an effective and scalable system for handling on-demand fusion queries over heterogeneous multi-source data, examples on how LLM's can fact check information more efficiently. </td>
                <td> Plan to further <strong>enhance the effectiveness of the on-demand fusion query</strong>. </td>
                <td> PVLDB (Proceedings of the VLDB Endowment) </td>
                <td><a href="../2_Papers%20to%20review/1_FusionQuery-On-demand%20Fusion%20Queries.pdf" target="_blank">1_FusionQuery-On-demand Fusion Queries.pdf</a></td>
            </tr>
            <tr>
                <td> Simon Kamm, Nasser Jazdi, Michael Weyrich </td>
                <td> Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches </td>
                <td> 2021 </td>
                <td> Heterogeneous Data, Industry 4.0, Internet of Things, Knowledge Discovery, Machine Learning, Semantic Data Integration, Unstructured Data </td>
                <td> Discusses challenges for <strong>Knowledge Discovery (KDD)</strong> in Industry 4.0 due to the increasing volume and heterogeneity of data, which often results in separated "data silos". </td>
                <td> To identify and analyze the challenges and necessary approaches for Knowledge Discovery in Industry 4.0 systems dealing with heterogeneous and unstructured data. </td>
                <td> Detailed concretization and comparative analysis of existing approaches. This work will specifically target industrial automation systems operating under challenging environmental conditions, such as strict timing requirements or distributed partial processes. </td>
                <td> Procedia CIRP </td>
                <td><a href="../2_Papers%20to%20review/1_Knowledge%20discovery%20in%20heterogeneous%20and%20unstructured%20data.pdf" target="_blank">1_Knowledge discovery in heterogeneous and unstructured data.pdf</a></td>
            </tr>
            <tr>
                <td> Theofanis P. Raptis, Andrea Passarella, Marco Conti </td>
                <td> Data Management in Industry 4.0: State of the Art and Open Challenges </td>
                <td> 2019 </td>
                <td> Data management, industrial networks, manufacturing, Industry 4.0 </td>
                <td> (Cites relevant papers useful for our basis) A survey reviewing data management issues (2015-2018) in <strong>networked industrial environments (Industry 4.0)</strong>, classifying relevant technologies and services. </td>
                <td> To survey the literature and identify open challenges for data management in the intersection of industrial automation and communication/networking fields. </td>
                <td> Open challenges include: <strong>Energy efficient data delivery</strong>; <strong>Data distribution in local and mobile clouds</strong>; <strong>Distributed, real-time data security</strong>; and Convergence between communications and industrial automation. </td>
                <td> IEEE Access </td>
                <td><a href="../2_Papers%20to%20review/2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf" target="_blank">2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf</a></td>
            </tr>
            <tr>
                <td> Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang </td>
                <td> A Survey on Deep Learning for Multimodal Data Fusion </td>
                <td> 2020 </td>
                <td> (Extracted from text) Deep Learning (DL), Multimodal Data Fusion, DBN, SAE, CNN, RNN, Semantic Fusion Strategies </td>
                <td> Surveys Deep Learning models designed for <strong>multimodal data fusion</strong>, categorizing approaches based on architectures like Deep Belief Networks (DBN) and Recurrent Neural Networks (RNN) among others. </td>
                <td> To provide an overview and summarize deep learning models developed for multimodal data fusion, built on current representative DL architectures. </td>
                <td> New DL models that take semantic relationships into consideration are urgently needed. Suggests combining deep learning with **semantic fusion strategies**. </td>
                <td> Neural Computation </td>
                <td><a href="../2_Papers%20to%20review/2_deeplearning_multimodal.pdf" target="_blank">2_deeplearning_multimodal.pdf</a></td>
            </tr>
            <tr>
                <td> Jun Wang, Xiaohan Li, Huading Jia, Tao Peng </td>
                <td> A graph-based approach to multi-source heterogeneous information fusion in stock market </td>
                <td> 2022 </td>
                <td> Graph fusion, Heterogeneous information/data, Relational dimension, Multi-attention graph neural network, Stock market price fluctuation/prediction, Complex network, Information spillover </td>
                <td> Proposes a graph fusion and embedding method using a multi-attention GNN to incorporate multi-source heterogeneous data and relational information for predicting stock market volatility. </td>
                <td> To establish a graph fusion and embedding method using relational dimension information for fusing heterogeneous data, and construct a GNN to mine implied semantics for stock price prediction. </td>
                <td> Expand node features (e.g., trading data derivative index, graphical data) and study the interaction mechanism of heterogeneous data. Explore building a public opinion monitoring function for securities market regulation. </td>
                <td> PLoS ONE </td>
                <td><a href="../2_Papers%20to%20review/2_graph-based%20multisource%20heterogeneous%20information%20fusion%20for%20stockmarket.pdf" target="_blank">2_graph-based multisource heterogeneous information fusion for stockmarket.pdf</a></td>
            </tr>
            <tr>
                <td> Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui </td>
                <td> Multi-Source Information Fusion Based Heterogeneous Network Embedding </td>
                <td> 2020 </td>
                <td> Heterogeneous Network Embedding, Multi-Source Information Fusion, Representation Learning, Joint Learning </td>
                <td> Proposes MIFHNE, a generic approach to enhance network embedding by integrating rich multi-source information (structural, semantic, attribute, and label data) in Heterogeneous Information Networks (HINs). </td>
                <td> To propose and validate the MIFHNE approach, demonstrating the importance of multi-source information fusion for network embedding in HINs. </td>
                <td> Future work is presented in Section 6. (will focus on the possibility of the attribute information of node being multimodal, basis for designing an efficient embedding method for heterogeneous network) </td>
                <td> [ScienceDirect] Information Sciences </td>
                <td><a href="../2_Papers%20to%20review/2_multisourceinformationfusionbasednetworkingembedding.pdf" target="_blank">2_multisourceinformationfusionbasednetworkingembedding.pdf</a></td>
            </tr>
            <tr>
                <td> Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli </td>
                <td> Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction </td>
                <td> 2021 </td>
                <td> Heterogeneous data sources, Data fusion, Radial Basis Functions (RBF), Deep Learning, Graph Convolutional Networks (GCN) </td>
                <td> Describes a data fusion pipeline where raw heterogeneous data is preprocessed/fused (e.g., via RBF function), then modeled using various ML Model (GCN/GCNN/STGCN) architectures for prediction. </td>
                <td> To construct a pipeline for heterogeneous data fusion and modeling using graph convolutional network architectures dedicated to AirQuality prediction. </td>
                <td> Not explicitly mentioned. </td>
                <td> Journal of King Saud University - Computer and Information Sciences </td>
                <td><a href="../2_Papers%20to%20review/3_datafusion_graphCNN.pdf" target="_blank">3_datafusion_graphCNN.pdf</a></td>
            </tr>
            <tr>
                <td> Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang </td>
                <td> Multi-source Heterogeneous Data Fusion Model Based on FC-SAE </td>
                <td> 2022 </td>
                <td> Multi-source heterogeneous, Data fusion, Deep learning, SAE, FC </td>
                <td> Proposes the FC-SAE model (Fully Connected Sparse Autoencoder) as a fusion mechanism to integrate time-series data and text data for enhanced forecasting accuracy. </td>
                <td> To propose an FC-SAE based multi-source heterogeneous data fusion model that breaks the structural barrier between time series data and text data. </td>
                <td> Not explicitly mentioned. </td>
                <td> Journal of Internet Technology </td>
                <td><a href="../2_Papers%20to%20review/4_datafusion_multisource.pdf" target="_blank">4_datafusion_multisource.pdf</a></td>
            </tr>
            <tr>
                <td> Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth </td>
                <td> A Multimodal Approach for Semantic Patent Image Retrieval </td>
                <td> 2021 </td>
                <td> Patent Image Similarity Search, Deep Learning, Mulitmodal Feature Representations, Scene Text Spotting </td>
                <td> Presents a multimodal retrieval system for patent images that extracts and fuses both textual features (from figure descriptions) and visual features (from images) using <strong>score re-ranking</strong>. </td>
                <td> To evaluate and improve the relevance of patent retrieval results using the multimodal feature fusion derived from patent images and their associated textual descriptions. </td>
                <td> Plan to exploit further information in images (e.g., non-numeric image text). Intend to incorporate multimodal information in an end-to-end network or joint framework. </td>
                <td> PatentSemTech </td>
                <td><a href="../2_Papers%20to%20review/5_multimodal_patentimage.pdf" target="_blank">5_multimodal_patentimage.pdf</a></td>
            </tr>
            <tr>
                <td> Jeonghun Jee, Sanghyun Park, Sungjoo Lee </td>
                <td> Potential of patent image data as technology intelligence source </td>
                <td> 2022 </td>
                <td> Patent analysis, Image data, Technology intelligence, Product structure, Network analysis, Block diagrams </td>
                <td> Investigates the potential of <strong>texts extracted specifically from patent block diagrams (images)</strong> as a crucial source of technology intelligence for structural analysis. </td>
                <td> To investigate the potential of patent image data, particularly text from block diagrams, to be used as a source of technology intelligence. </td>
                <td> Requires a more elaborated method for identifying meaningful terms using <strong>n-grams or pre-defined dictionaries</strong>. Future study needed to customize the approach to various other types of patent drawings. Investigate the potential value of combining subject-action-object (SAO) analysis with image analysis. </td>
                <td> [ScienceDirect] Journal of Informetrics </td>
                <td><a href="../2_Papers%20to%20review/6_patentimage.pdf" target="_blank">6_patentimage.pdf</a></td>
            </tr>
            <tr>
                <td> Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao </td>
                <td> Research on product appearance patent spatial shape recognition for multi-image feature fusion </td>
                <td> 2023 </td>
                <td> Design Patent Search System, Spatial Shape Recognition, Multi-image fusion, Image Segmentation, Contour Description </td>
                <td> Describes the system design and user interface functionality for a design patent search system specializing in spatial shape recognition, which relies on analyzing and fusing multiple images/views. </td>
                <td> To demonstrate a system and methodology for retrieving design patents based on spatial shape recognition using multi-image fusion. </td>
                <td> Not explicitly mentioned. </td>
                <td> [Springer] Multimedia Tools and Applications </td>
                <td><a href="../2_Papers%20to%20review/7_patentimage_spatialshapes.pdf" target="_blank">7_patentimage_spatialshapes.pdf</a></td>
            </tr>
            <tr>
                <td> Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang </td>
                <td> Multi-source heterogeneous data fusion </td>
                <td> 2018 </td>
                <td> Big data,Heterogeneous data, Data fusion,Heterogeneous data fusion, Deep learning </td>
                <td> Overview of the problems, challenges, and technologies associated with multi-source data fusion in the context of Big Data, referencing methodologies like Ensemble Learning and Deep Learning approaches. </td>
                <td> To overview problems and challenges associated with Big Data fusion, particularly emphasizing Deep Learning models for fusing heterogeneous sensor data. </td>
                <td> Not explicitly mentioned. </td>
                <td> IEEE Xplore </td>
                <td><a href="../2_Papers%20to%20review/8_Multi-source_heterogeneous_data_fusion.pdf" target="_blank">8_Multi-source_heterogeneous_data_fusion.pdf</a></td>
            </tr>
            <tr>
                <td> Sultan Baimukhanov, Hashim Ali, Adnan Yazici </td>
                <td> Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing </td>
                <td> 2025 </td>
                <td> IoT-Cloud Interaction, Data management in IoT, IoT security vulnerabilities, Anomaly detection, Explainable AI </td>
                <td> Proposes a system (SSPA) integrating Machine Learning (ML), IoT, Cloud Computing (CC), and Edge Computing (EC) to enhance anomaly detection specifically for security and data management in IoT environments. The system uses the iForest algorithm for anomaly detection. </td>
                <td> To explore the potential of integrating ML, IoT, CC, and EC to improve anomaly detection in data management and substantiate the practical applicability and viability of the proposed solution. </td>
                <td> Not explicitly mentioned. </td>
                <td> [ScienceDirect] Expert Systems With Applications </td>
                <td><a href="../2_Papers%20to%20review/2_Enhancing_MLbased%20anomaly%20detection%20in%20data%20management%20for%20security%20on%20integration%20of%20iot.pdf" target="_blank">2_Enhancing_MLbased anomaly detection in data management for security on integration of iot.pdf</a></td>
            </tr>
            <tr>
                <td> Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza </td>
                <td> Artificial Intelligence in manufacturing: State of the art, perspectives, and future directions </td>
                <td> 2024 </td>
                <td> Artificial intelligence, Smart manufacturing, Machine learning </td>
                <td> Reviews state-of-the-art AI applications (model-based & data-driven) across the manufacturing lifecycle (design, process, quality, assembly) to guide the realization of smart manufacturing (well updated and analyzing current trends). </td>
                <td> To present advances in AI in manufacturing with an integrated view of system, process, quality, and (dis)assembly, map AI technologies to manufacturing tasks, and outline emerging challenges and future directions. </td>
                <td> Expand on unsupervised learning, <strong>integrating physics with AI</strong>, developing <strong>causal AI</strong>, adopting next-generation <strong>Generative AI</strong> and <strong>Generalist AI models (LLMs)</strong>, researching <strong>AI-specific hardware</strong>, and focusing on <strong>real-life AI introduction</strong> (trustworthiness). </td>
                <td> [ScienceDirect] CIRP Annals - Manufacturing Technology </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf" target="_blank">1_(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf</a></td>
            </tr>
            <tr>
                <td> Amit Mithal, Blessy Thankachan </td>
                <td> A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management </td>
                <td> 2025 </td>
                <td> Blockchain Technology, Machine Learning (ML), Deep Learning (DL), Groundwater Conservation, Wastewater Management, Data Integrity, Anomaly Detection, Resource Optimization, Regulatory Compliance </td>
                <td> A systematic review (2019-2025) of 97 peer-reviewed articles analyzing the convergence of **Blockchain, Machine Learning (ML), and Deep Learning (DL)** to enhance sustainability, maintain data integrity, and optimize resource utilization in the water sector. </td>
                <td> To systematically analyze recent technological advances, evaluate performance improvements achieved through Blockchain/AI integration, and identify critical research gaps and future directions for sustainable water resource management. </td>
                <td> The abstract confirms the identification of **research gaps and future directions** (e.g., improved data validation, resource optimization, transparency). </td>
                <td> Environmental Management </td>
                <td><a href="../2_Papers%20to%20review/1_(Important)A%20review%20on%20blockchain%20for%20water%20mngmnt.pdf" target="_blank">1_(Important)A review on blockchain for water mngmnt.pdf</a></td>
            </tr>
            <tr>
                <td> Nikita V. Golovastikov, Nikolay L. Kazanskiy, and Svetlana N. Khonina </td>
                <td> Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure </td>
                <td> 2025 </td>
                <td> Optical Fiber Sensors (OFS), Structural Health Monitoring (SHM), Dams, Pipelines, Distributed Acoustic Sensing (DAS), Water Management, Artificial Intelligence (AI) </td>
                <td> A comprehensive review of <strong>Optical Fiber Sensors (OFS)</strong> for <strong>Structural Health Monitoring (SHM)</strong>, specifically detailing their application in monitoring the structural integrity, seepage, leakage, and dynamic conditions of <strong>dams, water management infrastructure, and long-distance pipelines</strong>. </td>
                <td> To review the latest advancements, applications, and integration of OFS and AI/Machine Learning techniques for SHM in civil and urban infrastructure, including critical water assets. </td>
                <td> <strong>Develop more dynamic Digital Twin models for real-time monitoring</strong>. <strong>Establish standardization of test procedures and calibration for OFS</strong>. </td>
                <td> Photonics </td>
                <td><a href="../2_Papers%20to%20review/3_Optical%20Fiber-Based%20Structural%20Health%20Monitoring.pdf" target="_blank">3_Optical Fiber-Based Structural Health Monitoring.pdf</a></td>
            </tr>
            <tr>
                <td> Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu </td>
                <td> Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0 </td>
                <td> 2025 </td>
                <td> Directed Acyclic Graphs (DAGs), Ensemble Learning, Predictive Maintenance, Industry 4.0, Machine Learning, Failure Prediction </td>
                <td> Proposes a novel approach using <strong>Directed Acyclic Graphs (DAGs)</strong> to <strong>ensemble multiple machine learning models</strong>, enabling more robust and accurate failure predictions for <strong>Predictive Maintenance</strong> in Industry 4.0. </td>
                <td> To propose a novel approach using Directed Acyclic Graphs (DAGs) to ensemble multiple machine learning models, enabling more robust and accurate failure predictions. </td>
                <td> Not explicitly mentioned in the abstract. </td>
                <td> 2025 International Conference on Next Generation Communication & Information Processing (INCIP) </td>
                <td><a href="../2_Papers%20to%20review/1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf" target="_blank">1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf</a></td>
            </tr>
            <tr>
                <td> Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A </td>
                <td> HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration </td>
                <td> 2025 </td>
                <td> IoT, Water Quality Monitoring, Machine Learning, Cloud Integration, ESP32, Real-time Alerts, Public Health </td>
                <td> Presents HydroSense 2.0, an intelligent water quality monitoring system using <strong>IoT sensors (pH, temperature, turbidity, TDS)</strong>, an ESP32 microcontroller, and <strong>machine learning models</strong> for real-time surveillance and automated alerts. </td>
                <td> To develop and deploy a comprehensive, real-time, automated water quality surveillance system (HydroSense 2.0) integrated with cloud computing and machine learning to address public health and safety concerns. </td>
                <td> Not explicitly mentioned in the abstract. </td>
                <td> 2025 International Conference on Computing Technologies & Data Communication (ICCTDC) </td>
                <td><a href="../2_Papers%20to%20review/1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf" target="_blank">1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf</a></td>
            </tr>
            <tr>
				<td>Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami</td>
				<td>Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights</td>
				<td>2021</td>
				<td>Structural health monitoring, machine learning, internet of things, big data, emerging technologies</td>
				<td>A review clarifying and summarizing the Machine Learning (ML) pipelines and frontiers in modern Structural Health Monitoring (SHM) systems, with a focus on emerging technologies like IoT, Big Data, UAVs, AR/VR, and Digital Twins.</td>
				<td>To clarify and review the ML frontiers involved in modern SHM systems, detailing ML pipelines, tools, and algorithms, and exploring the connection to next-generation technologies and data science prospects for SHM.</td>
				<td>The article examines current and future challenges and open research issues in the SHM-ML conjunction and offers an outlook on the future of monitoring civil infrastructure integrity.</td>
				<td>Structural Health Monitoring</td>
				<td><a href="../2_Papers%20to%20review/3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf" target="_blank">3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf</a></td>
			</tr>
            <tr>
				<td>Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam</td>
				<td>Big Data analytics and IoT in Operation safety management in Under Water Management</td>
				<td>2020</td>
				<td>Big Data Analytics, Internet of Things, Water management, Sensors, WSN</td>
				<td>The paper proposes a Supervisory Control and Data Acquisition (SCADA) approach using IoT and Big Data Analytics for sustainable smart water management. Experimental results demonstrate that this implementation proactively controls water usage and achieves higher levels of sustainable water supply.</td>
				<td>To propose a Mathematical model and demonstrate the Supervisory Control and Data Acquisition (SCADA) method for smart water management using IoT and Big Data Analytics, including remote environmental monitoring using Raspberry Pi and Python.</td>
				<td>The authors recommend developing more models using Big Data and IoT for long-term evaluation and scheduling of water distribution networks, performing multi-periodic leakage stream analysis, and expanding performance analyses to include natural and man-made disasters (e.g., earthquakes, thefts, and terrorism).</td>
				<td>Computer Communications</td>
				<td><a href="../2_Papers%20to%20review/2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf" target="_blank">2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf</a></td>
			</tr>
            <tr>
				<td>N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas</td>
				<td>A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities</td>
				<td>2020</td>
				<td>Internet of things, Flood analytics information system, Machine learning, Big Data, Flood situational awareness</td>
				<td>Presents a national-scale Flood Analytics Information System (FAIS) as a Python Web application. This system gathers Big Data from multiple sources, integrates crowd intelligence, Machine Learning (ML), and Natural Language Processing (NLP) of tweets to provide flood warnings and improve situational awareness for flood risk management.</td>
				<td>To develop and demonstrate the capabilities of the Flood Analytics Information System (FAIS) to assess flooding impacts during historical and real-time events by leveraging IoT, Big Data, ML, and crowd-sourced intelligence.</td>
				<td>The paper suggests expanding the system's spatial coverage (beyond The Carolinas) and integrating more detailed infrastructure and socio-economic data for improved vulnerability assessments.</td>
				<td>Environmental Modelling and Software</td>
				<td><a href="../2_Papers%20to%20review/2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf" target="_blank">2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf</a></td>
			</tr>
            <tr>
				<td>Inês Figueiredo, Paulo Esteves, Paulo Cabrita</td>
				<td>Water wise – a digital water solution for smart cities and water management entities</td>
				<td>2021</td>
				<td>Digital water, Smart cities, Water management, Water-Energy Nexus, IoT, Decision support system</td>
				<td>Presents the 'Water Wise System' (W2S), a digital water solution developed to efficiently manage the urban water cycle. The system utilizes real-time monitoring, a decision support system, and addresses the water-energy nexus for smart cities.</td>
				<td>To present a preliminary study of the architecture and software solution for the Water Wise System (W2S), focusing on water management challenges, available technology, Digital Water, IoT, and the future of smart cities.</td>
				<td>The paper outlines a plan for future work on the software solution to support full water supply network management, including integration with EPANET 2 (a water flow modeling software).</td>
				<td>Procedia Computer Science</td>
				<td><a href="../2_Papers%20to%20review/1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf" target="_blank">1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf</a></td>
			</tr>
            <tr>
				<td>Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris</td>
				<td>Making urban water smart: the SMART-WATER solution</td>
				<td>2020</td>
				<td>Internet of Things, LPWAN, predictive big data analytics, smart metering, machine learning</td>
				<td>Proposes a unified framework called SMART-WATER for urban water management. It exploits state-of-the-art IoT solutions for remote telemetry and control, combined with machine learning-based processes to enhance water management and decision-making.</td>
				<td>To propose and describe the SMART-WATER platform, a unified framework aimed at supporting water utility companies by providing innovative solutions for smart water utilization, enhancing management, and decision-making processes.</td>
				<td>The paper does not explicitly detail future work or improvements, focusing instead on the proposed framework and its current capabilities.</td>
				<td>Water Science & Technology</td>
				<td><a href="../2_Papers%20to%20review/2_MakingurbanwatersmarttheSMART-WATERsolution.pdf" target="_blank">2_MakingurbanwatersmarttheSMART-WATERsolution.pdf</a></td>
			</tr>
            <tr>
				<td>Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein</td>
				<td>Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review</td>
				<td>2020</td>
				<td>Digital water meter, smart metering, machine learning, data analytic, water consumption prediction, water consumption pattern classification, leakage detection</td>
				<td>A review summarizing the application of Machine Learning (ML) and Data Analytic (DA) techniques across the various use-cases of digital water metering, including water consumption prediction, pattern classification, and leakage detection. The paper discusses various algorithms and future challenges.</td>
				<td>To systematically review the application of ML and DA techniques in analyzing data generated by digital water meters, categorize existing research, and discuss future research challenges and opportunities in this field.</td>
				<td>Challenges include developing efficient ML techniques for real-time applications, managing privacy and security, integrating with smart grids and other IoT systems, and optimizing algorithms for large-scale, heterogeneous data.</td>
				<td>Water</td>
				<td><a href="../2_Papers%20to%20review/2_MachineLearningandDataAnalyticTechniquesin.pdf" target="_blank">2_MachineLearningandDataAnalyticTechniquesin.pdf</a></td>
			</tr>
            <tr>
				<td>Sunil Sinha and Lee Sears</td>
				<td>Collection and Compilation of Water Pipeline Field Performance Data</td>
				<td>2017</td>
				<td>Water pipeline, data collection, pipeline reliability, data standardization, database development, GIS</td>
				<td>Presents the objectives and phases of a project aimed at collecting, compiling, and analyzing high-quality field data on pipeline reliability performance from utilities across the U.S., Canada, and Australia. It focuses on developing a Web-based, GIS-enabled national pipeline database (PIPEID).</td>
				<td>To outline a project to collect, compile, and analyze high-quality field data on pipeline reliability performance for various materials, and to establish a standardized, GIS-enabled water pipeline database (PIPEID).</td>
				<td>Phase II of the project, which involves model development, demonstration, benchmarking, and validation, is planned to follow the data collection and standardization of Phase I. Future work emphasizes data integration (physical, operational, environmental, social, and financial) as the key challenge.</td>
				<td>Pipelines 2017 (Conference Proceedings)</td>
				<td><a href="../2_Papers%20to%20review/2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf" target="_blank">2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf</a></td>
			</tr>
        </tbody>
    </table>
</div>
"""

display(HTML(content_html))
# Out:
# <div style="width: 100%; height: 600px; overflow: auto; border: 2px solid #007bff; padding: 5px;">
# <style>
#     /* Ensures the table is very wide (180%) to force horizontal scrolling */
#     table { width: 180%; border-collapse: collapse; font-size: 14px; }
#
#     /* Border color set to #bbb (grayish) */
#     th, td { border: 1px solid #bbb; padding: 8px; text-align: left; vertical-align: top; }
#
#     /* Header background, bold, and text color set to black */
#     th { background-color: #f2f2f2; font-weight: bold; color: black; }
#
#     /* Style the wide columns (General Idea, Objective, Future Work) to be more readable */
#     td:nth-child(5), td:nth-child(6), td:nth-child(7) { min-width: 200px; }
#
#     /* Set a minimum width for the new Journal/Publication column */
#     td:nth-child(8) { min-width: 150px; }
#
#     /* MODIFIED: Force the Source File Name column to break words and be narrower */
#     td:nth-child(9) {
#         min-width: 100px;
# ...
