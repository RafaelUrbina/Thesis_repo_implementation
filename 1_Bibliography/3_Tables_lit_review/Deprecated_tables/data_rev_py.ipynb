# %%
import pandas as pd
from itables import show

data = [
    {
        "Authors": "Jihong yan, Yue meng, Lei lu, Lin li",
        "Title": "Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance",
        "Year": 2017,
        "Data types used": "Industrial Big Data, Multisource heterogeneous data (Temperature signals, Vibration signals), unstructured/semi-structured information, environmental data consideration of the spatiotemporal properties,staff behaviour, cost information, customer information, unstructured data extracted from XML files, annotations in textual data, ontology concepts, video surveillance, weather forecast data, humidity data.",
        "Sources of the data used": "Condition monitoring and test data, multisource sensors, intercommunication, and external-related information (machining equipment components).",
        "Periodicity of the data (if available)": "Diverse sampling frequencies: Vibration (10 kHz to 100 kHz).",
        "Source File Name": "1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf"
    },
    {
        "Authors": "Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr",
        "Title": "Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies",
        "Year": 2019,
        "Data types used": "Corpus documents (119 articles) covering technologies, refer to Table X, (gruped technologies).",
        "Sources of the data used": "Corpus collected from searching EBSCOhost, Web of Science, and ScienceDirect databases.",
        "Periodicity of the data (if available)": "Survey period covered literature published up to July 2017.",
        "Source File Name": "1_(done)(irene)Industry4 as data-driven and technologies 2021.pdf"
    },
    {
        "Authors": "Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza",
        "Title": "Artificial Intelligence in manufacturing: State of the Art, Perspectives, and Future Directions",
        "Year": 2024,
        "Data types used": "In-process sensing data, time series data, image data, and acoustic signals.",
        "Sources of the data used": "Data derived from various manufacturing processes (e.g., milling tools).",
        "Periodicity of the data (if available)": "Time series data. Tool wear prediction is guided to increase monotonically as cutting cycle increases.",
        "Source File Name": "1_(done)(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf"
    },
    {
        "Authors": "Lian Duan, Li Da Xu",
        "Title": "Data Analytics and Industry 4.0: Survey",
        "Year": 2021,
        "Data types used": "Big Data, including historical data, structured, semi-structured, and unstructured data. CSV, JSON, XML.",
        "Sources of the data used": "The survey's own analysis data sources: Scopus data and Google Scholar data.",
        "Periodicity of the data (if available)": "The analysis of trends covers the period from 2014 to 2022. Data warehouses save historical data.",
        "Source File Name": "1_(done)(irene)data analytics industry4 survey 2024.pdf"
    },
    {
        "Authors": "Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider",
        "Title": "5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models",
        "Year": 2021,
        "Data types used": "Product-instance-centric information necessary for digital continuity, real-time data, engineering data, simulation data, and operational data.",
        "Sources of the data used": "Data related to the USAF digital thread initiative(on the references, else not explicitly mentioned).",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf"
    },
    {
        "Authors": "Weiming Liu, Chen Zhang, Bin Yu, Yitong Li",
        "Title": "A General Multi-Source Data Fusion Framework",
        "Year": 2019,
        "Data types used": "Multi-source structured data, semi-structured data, and unstructured data. Data models fused: paper data model and college data model. Unified format: RDF Resource  Description Framework, Textual data.",
        "Sources of the data used": "Relational database, Online encyclopedias, blogs, and other Web sites.",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "1_A General Multi-source data fusion framework.pdf"
    },
    {
        "Authors": "Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan",
        "Title": "A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion",
        "Year": 2022,
        "Data types used": "Multi-source heterogeneous data including Transaction data, News texts, and Graphical indicators (K-line, 5-day EMA, 10-day EMA).",
        "Sources of the data used": "China Stock Market & Accounting Research (CSMAR) database.",
        "Periodicity of the data (if available)": "Data range from 2013-01-11 to 2019-11-25. Transaction data uses features aggregated over 5 trading days.",
        "Source File Name": "1_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf"
    },
    {
        "Authors": "Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee",
        "Title": "Enabling technologies and tools for digital twin",
        "Year": 2021,
        "Data types used": "Raw data (incomplete, unstructured, noisy, fuzzy, and random). Stored data types include semi-structured and unstructured data. Focus on the tools for data processing, check the tables included in the paper.",
        "Sources of the data used": "Requires a real-time read-write distributed database. Mentions using tools like FEA software ANSYS.",
        "Periodicity of the data (if available)": "Requires real-time data processing and storage.",
        "Source File Name": "1_Enabling technologies and tools for digital twin.pdf"
    },
    {
        "Authors": "Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao",
        "Title": "FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data",
        "Year": 2024,
        "Data types used": "Multi-source heterogeneous data. Specific formats: JSON, 210KG, CSV, and XML. Datasets cover Movie, Book, Flight, and Stock data.",
        "Sources of the data used": "Four real-world benchmark datasets collected from various sources (IMDb and wikidata).",
        "Periodicity of the data (if available)": "Framework is adaptive to frequent data updates; performance measured against typical update interval of real-world data lakes.",
        "Source File Name": "1_FusionQuery-On-demand Fusion Queries.pdf"
    },
    {
        "Authors": "Simon Kamm, Nasser Jazdi, Michael Weyrich",
        "Title": "Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches",
        "Year": 2021,
        "Data types used": "Heterogeneous data (structural/syntactical variation and semantic variation) and unstructured data. Includes different types of sensor data, Optical, Acoustic and others.",
        "Sources of the data used": "Data isolated in separate \"data silos\". Sources originate from multiple sensors from different companies, not explicitly mentioned.",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "1_Knowledge discovery in heterogeneous and unstructured data.pdf"
    },
    {
        "Authors": "Theofanis P. Raptis, Andrea Passarella, Marco Conti",
        "Title": "Data Management in Industry 4.0: State of the Art and Open Challenges",
        "Year": 2019,
        "Data types used": "Data characterized by volume, variety, traffic, and criticality. Examples include machine energy consumption profiles, vibration data, and data derived from RFID tags.",
        "Sources of the data used": "Data is sourced from networked industrial environments, industrial sensors, and acquired using FPGA-based reconfigurable data acquisition systems.",
        "Periodicity of the data (if available)": "Data is collected for archival and in real time. Real-time data acquisition is achieved via FPGA-based reconfigurable data acquisition systems.",
        "Source File Name": "2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf"
    },
    {
        "Authors": "Sultan Baimukhanov, Hashim Ali, Adnan Yazici",
        "Title": "Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing",
        "Year": 2025,
        "Data types used": "IoT-generated information and IoT sensor readings.",
        "Sources of the data used": "IoT devices transmitting data through Edge and Cloud computing environments.",
        "Periodicity of the data (if available)": "Mentions capability for real-time monitoring.",
        "Source File Name": "2_Enhancing_MLbased anomaly detection in data management for security on integration of iot.pdf"
    },
    {
        "Authors": "Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang",
        "Title": "A Survey on Deep Learning for Multimodal Data Fusion",
        "Year": 2020,
        "Data types used": "Multimodal data. Examples include MRI and PET data (images), pose views features, and fusion of visual systems data with unannotated text.",
        "Sources of the data used": "Sources relate to medical imaging (MRI/PET) and general visual systems.",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "2_deeplearning_multimodal.pdf"
    },
    {
        "Authors": "Jun Wang, Xiaohan Li, Huading Jia, Tao Peng",
        "Title": "A graph-based approach to multi-source heterogeneous information fusion in stock market",
        "Year": 2022,
        "Data types used": "Multi-source heterogeneous information consisting of Transaction data (financial time series) and Stock news text data.",
        "Sources of the data used": "CMSAR database (China Stock Market & Accounting Research Database). News text data obtained via internet crawling.",
        "Periodicity of the data (if available)": "Data ranges from January 1, 2016, to December 31, 2020.",
        "Source File Name": "2_graph-based multisource heterogeneous information fusion for stockmarket.pdf"
    },
    {
        "Authors": "Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui",
        "Title": "Multi-Source Information Fusion Based Heterogeneous Network Embedding",
        "Year": 2020,
        "Data types used": "Heterogeneous network data composed of authors, papers, and venues (nodes and relationships). Node features include title content (text data).",
        "Sources of the data used": "Two real-world network datasets: DBLP Heterogeneous Network and ACM Heterogeneous Network.",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "2_multisourceinformationfusionbasednetworkingembedding.pdf"
    },
    {
        "Authors": "Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli",
        "Title": "Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction",
        "Year": 2021,
        "Data types used": "Continuous heterogeneous data (meteorological monitoring data and air quality monitoring data). Data is represented as graph-structured data and time series data.",
        "Sources of the data used": "Real dataset related to air quality in Beijing, collected from the Harvard Dataverse (35 meteorological stations and 17 air quality stations).",
        "Periodicity of the data (if available)": "Data records are collected every hour. Collection period: January 1, 2017, to February 1, 2018.",
        "Source File Name": "3_datafusion_graphCNN.pdf"
    },
    {
        "Authors": "Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang",
        "Title": "Multi-source Heterogeneous Data Fusion Model Based on FC-SAE",
        "Year": 2022,
        "Data types used": "Multi-source heterogeneous time series data. Includes time series data (daily taxi traveling data), event text description data (unstructured text), and weather data.",
        "Sources of the data used": "Taxi traveling record data set related to the transportation domain.",
        "Periodicity of the data (if available)": "Original data is aggregated to produce daily taxi traveling data. Training set: January 2013 to September 2014 , Validation set: October to December 2014. Test set: January 2015 to June 2016.",
        "Source File Name": "4_datafusion_multisource.pdf"
    },
    {
        "Authors": "Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth",
        "Title": "A Multimodal Approach for Semantic Patent Image Retrieval",
        "Year": 2021,
        "Data types used": "Multimodal data combining Textual Features (keywords, titles, etc.) and Visual Features (from patent images).",
        "Sources of the data used": "Patent documents.",
        "Periodicity of the data (if available)": "Not explicitly mentioned.",
        "Source File Name": "5_multimodal_patentimage.pdf"
    },
    {
        "Authors": "Jeonghun Jee, Sanghyun Park, Sungjoo Lee",
        "Title": "Potential of patent image data as technology intelligence source",
        "Year": 2022,
        "Data types used": "Patent image data (text extracted from block diagrams), and Descriptive patent data. Analysis uses a Binary patent-to-keyword matrix.",
        "Sources of the data used": "Data extracted from patent documents. Images sourced from the Google Patent site.",
        "Periodicity of the data (if available)": "Patents grouped into four periods for time series analysis: P1 (2010–2011), P2 (2012–2013), P3 (2014–2015), and P4 (2016–2017).",
        "Source File Name": "6_patentimage.pdf"
    },
    {
        "Authors": "Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao",
        "Title": "Research on product appearance patent spatial shape recognition for multi-image feature fusion",
        "Year": 2023,
        "Data types used": "Image data focused on appearance design patent images. Features analyzed include shape features and texture features.",
        "Sources of the data used": "Design patent base/documents, Smart buds patent Data base.",
        "Periodicity of the data (if available)": "Smart buds patent Data base from January 2011 till December 2020",
        "Source File Name": "7_patentimage_spatialshapes.pdf"
    },
    {
        "Authors": "Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang",
        "Title": "Multi-source heterogeneous data fusion",
        "Year": 2018,
        "Data types used": "Multi-source heterogeneous information, discussion on Multi-source domain adaptation, cross-media big data, and multimedia big data.",
        "Sources of the data used": "Sources implicitly include generalized big data systems and reference points.",
        "Periodicity of the data (if available)": "Not explicitly mentioned (Used).",
        "Source File Name": "8_Multi-source_heterogeneous_data_fusion.pdf"
    },
    {
        "Authors": "Amit Mithal, Blessy Thankachan",
        "Title": "A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management",
        "Year": 2025,
        "Data types used": "Water quality monitoring data (e.g., pH, dissolved oxygen, turbidity), sensor data (IoT-based monitoring), groundwater level data, real-time consumption records, transactional data (for resource trading/compliance), hydrological model outputs, and ML/DL derived data (for anomaly detection, pollution prediction).",
        "Sources of the data used": "IoT sensing infrastructure (distributed across water networks), regulatory databases, smart meters, hydrological monitoring stations, satellite data (used in some reviewed papers for context/modeling), and the Blockchain ledger itself (for secure, validated records).",
        "Periodicity of the data (if available)": "Real-time or near-real-time sensor data acquisition (depending on the IoT implementation), with archival records stored on the blockchain.",
        "Source File Name": "1_(Important)A review on blockchain for water mngmnt.pdf"
    },
    {
        "Authors": "Nikita V. Golovastikov, Nikolay L. Kazanskiy, Svetlana N. Khonina",
        "Title": "Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure",
        "Year": 2025,
        "Data types used": "Distributed and localized sensor data (Strain, Temperature, Vibration), Time-series data, Displacement/Deformation measurements, Acoustic Emission data, Multi-sensor heterogeneous data streams, and Annotated data (for damage detection/classification models).",
        "Sources of the data used": "Fiber Optic Sensors (FOS), including Fiber Bragg Grating (FBG) sensors and Distributed Fiber Optic Sensors (DFOS) embedded within civil infrastructure (bridges, tunnels, buildings). Data Acquisition Systems (DAS) and related AI processing units.",
        "Periodicity of the data (if available)": "High-frequency (kHz range) distributed sensing data, allowing for real-time monitoring of dynamic structural responses (e.g., vibration analysis).",
        "Source File Name": "3_Optical Fiber-Based Structural Health Monitoring.pdf"
    },
    {
        "Authors": "Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu",
        "Title": "Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0",
        "Year": 2025,
        "Data types used": "Time series sensor data (e.g., vibration, temperature, pressure), Failure labels (RUL or binary), Historical run-to-failure data, Operational parameters (speed, load), and Derived features from raw sensor signals (e.g., statistical features, frequency domain features).",
        "Sources of the data used": "Industrial equipment sensors (IIoT), NASA Ames Prognostics Data Repository (specifically Turbofan Engine Degradation Simulation Dataset mentioned as a common benchmark), and specialized machinery databases.",
        "Periodicity of the data (if available)": "High-frequency time-series data (for capturing machine health changes), with specific sensor rates depending on the equipment (e.g., daily snapshots for RUL, or high kHz for vibration data).",
        "Source File Name": "1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf"
    },
    {
        "Authors": "Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A",
        "Title": "HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration",
        "Year": 2025,
        "Data types used": "Water quality sensor readings (pH, Temperature, Turbidity, Total Dissolved Solids - TDS), Historical training data (labeled for quality/contamination status), and Machine Learning model output (classification/alert status).",
        "Sources of the data used": "IoT deployment using ESP32 microcontroller interfaced with industry-grade physical sensors (pH, Temperature, Turbidity, TDS probes) deployed in water bodies. Data is transmitted to an integrated Cloud platform (e.g., Google Cloud/AWS) for storage and processing.",
        "Periodicity of the data (if available)": "Real-time or near-real-time acquisition (data streamed from sensors every few seconds/minutes to the cloud platform).",
        "Source File Name": "1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf"
    },
    {
        "Authors": "Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami",
        "Title": "Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights",
        "Year": 2021,
        "Data types used": "High-dimensional data, Time-series data (vibration, strain, acceleration, displacement), Image/Video data (from UAVs and cameras), LiDAR/Point cloud data, Multi-sensor heterogeneous data, Spatiotemporal data, Seismic data, Acoustic data, Thermal data.",
        "Sources of the data used": "Conventional SHM sensors (accelerometers, strain gauges, fiber optics), Wireless Sensor Networks (WSNs), Internet of Things (IoT) sensors, Unmanned Aerial Vehicles (UAVs), Smartphones, External databases (e.g., climate, traffic, earthquake data).",
        "Periodicity of the data (if available)": "Focuses on near real-time and online assessment; periodicity is highly diverse and often high-frequency (e.g., dynamic monitoring) depending on the Structural Health Monitoring (SHM) method.",
        "Source File Name": "3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf"
    },
    {
        "Authors": "Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam",
        "Title": "Big Data analytics and IoT in Operation safety management in Under Water Management",
        "Year": 2020,
        "Data types used": "Operational data (e.g., water usage, flow rates), Environmental sensor data (e.g., water quality parameters), SCADA data, Big Data streams.",
        "Sources of the data used": "Internet of Things (IoT) sensors, Wireless Sensor Networks (WSN), Supervisory Control and Data Acquisition (SCADA) systems, Raspberry Pi remote monitoring devices.",
        "Periodicity of the data (if available)": "The system is designed for real-time monitoring and proactive control, implying continuous or near real-time data collection.",
        "Source File Name": "2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf"
    },
    {
        "Authors": "N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas",
        "Title": "A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities",
        "Year": 2020,
        "Data types used": "Big Data (heterogeneous data streams), Social Media data (Twitter/Tweets for crowd intelligence, text data for Natural Language Processing), Geographic Information System (GIS) data (spatial flood data, critical infrastructure locations), Historical and Real-time event data.",
        "Sources of the data used": "Multiple servers/Big Data infrastructure, Internet of Things (IoT) devices, Social media platforms (Twitter/X), Historical flood models and records, U.S. Geological Survey (USGS) for elevation and land data.",
        "Periodicity of the data (if available)": "Designed to gather and analyze data during both historical and **real-time** events, implying continuous or near real-time data ingestion for situational awareness.",
        "Source File Name": "2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf"
    },
    {
        "Authors": "Inês Figueiredo, Paulo Esteves, Paulo Cabrita",
        "Title": "Water wise – a digital water solution for smart cities and water management entities",
        "Year": 2021,
        "Data types used": "Water demand data, Operational water supply network data (e.g., flow, pressure), Energy consumption data (Water-Energy Nexus), Financial data, Sensor data (from IoT infrastructure).",
        "Sources of the data used": "IoT sensors and devices for real-time monitoring, SCADA systems (implied for operational data), external systems for energy data and financial/billing information.",
        "Periodicity of the data (if available)": "Designed for **real-time monitoring** of the urban water cycle, supporting a Decision Support System (DSS).",
        "Source File Name": "1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf"
    },
    {
        "Authors": "Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris",
        "Title": "Making urban water smart: the SMART-WATER solution",
        "Year": 2020,
        "Data types used": "Water consumption data (e.g., flow, volume), Real-time telemetry data, Smart metering data, Network state and operational data, Big Data streams (for predictive analytics).",
        "Sources of the data used": "Internet of Things (IoT) sensors and devices, Low Power Wide Area Network (LPWAN) infrastructure, Smart meters, Water utility SCADA/telemetry systems.",
        "Periodicity of the data (if available)": "Designed for **remote telemetry and control**, implying continuous or near real-time data acquisition for monitoring and predictive analytics.",
        "Source File Name": "2_MakingurbanwatersmarttheSMART-WATERsolution.pdf"
    },
    {
        "Authors": "Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein",
        "Title": "Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review",
        "Year": 2020,
        "Data types used": "Water consumption data (e.g., flow rate, volume), Time-series data, Customer metadata/demographics (for consumption pattern classification), Meter readings (often electronic and frequent).",
        "Sources of the data used": "Digital water meters (or intelligent water meters), Smart metering infrastructure.",
        "Periodicity of the data (if available)": "High-frequency data (digital meters can frequently send consumption information electronically), suitable for **real-time** applications like leakage detection and consumption pattern analysis.",
        "Source File Name": "2_MachineLearningandDataAnalyticTechniquesin.pdf"
    },
    {
        "Authors": "Sunil Sinha and Lee Sears",
        "Title": "Collection and Compilation of Water Pipeline Field Performance Data",
        "Year": 2017,
        "Data types used": "Pipeline Reliability Performance Data, Infrastructure Inventory Data (material type: cast iron, ductile iron, concrete, steel, PVC, AC, etc.), Physical Data, Operational Data, Environmental Data, Social Data, Financial Data, Condition Assessment Data.",
        "Sources of the data used": "U.S. Bureau of Reclamation (USBR), U.S., Canadian, and Australian Water Utilities, Web-based, GIS-enabled national pipeline database (PIPEID), Various data collection projects (Phase I).",
        "Periodicity of the data (if available)": "The data collected is largely **static** (infrastructure inventory) and **historical** (reliability performance), with a goal of future integration to support dynamic modeling.",
        "Source File Name": "2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf"
    },   
]

# 2. Create the DataFrame
df = pd.DataFrame(data)

# 3. Render the interactive table (Sorting and filtering are enabled by these parameters)
show(df, 
      lengthMenu=[5, 10, 25], 
      classes=["display", "cell-border"], 
      caption="Literature Review (Interactive and Filterable)",
      dom="<lfipt>",
      init_js=[
          """
          // Add text input for filtering below each column header
          var api = this.api();
          api.columns().every(function() {
              var column = this;
              var input = $('<input type="text" placeholder="Filter..." />')
                  .appendTo($(column.footer()).empty())
                  .on('keyup change clear', function() {
                      if (column.search() !== this.value) {
                          column.search(this.value).draw();
                      }
                  });
              // This is needed because iTables puts the table in the thead/tfoot when rendering
              $(input).parent().parent().parent().addClass("filter_row");
          });
          """
      ]
)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_79e8e202_893f_49f0_b902_4730b8659d91"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
from IPython.display import HTML, display

content_html = r"""
<div style="width: 100%; height: 600px; overflow: auto; border: 2px solid #007bff; padding: 5px;">
    <style>
        /* Ensures the table is wide to enable horizontal scrolling if needed */
        table { width: 100%; border-collapse: collapse; font-size: 14px; }
        
        /* Border color set to #bbb (grayish) */
        th, td { border: 1px solid #bbb; padding: 8px; text-align: left; vertical-align: top; } 
        
        /* Header background, bold, and text color set to black */
        th { background-color: #f2f2f2; font-weight: strong; color: black; }
        
        /* Style the wide columns (Data types, Sources) to be more readable */
        td:nth-child(4), td:nth-child(5) { min-width: 250px; }
        
        /* MODIFIED: Source File Name column to break words and be narrower */
        td:nth-child(7) { 
            min-width: 150px; 
            word-break: break-all; 
        }
    </style>

    <table>
        <thead>
            <tr>
                <th>Authors</th>
                <th>Title</th>
                <th>Year</th>
                <th>Data types used</th>
                <th>Sources of the data used</th>
                <th>Periodicity of the data (if available)</th>
                <th>Source File Name</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td> Jihong yan, Yue meng, Lei lu, Lin li </td>
                <td> Industrial Big Data in an Industry 4.0 Environment: Challenges, Schemes, and Applications for Predictive Maintenance </td>
                <td> 2017 </td>
                <td> <strong>Industrial Big Data</strong>, <strong>Multisource heterogeneous data</strong> (<strong>Temperature signals, Vibration signals</strong>), <strong>unstructured/semi-structured information</strong>, <strong>environmental data</strong> consideration of the spatiotemporal properties,staff behaviour, cost information, customer information, unstructured data extracted from XML files, annotations in textual data, ontology concepts, video surveillance, weather forecast data, humidity data. </td>
                <td> <strong>Condition monitoring and test data</strong>, <strong>multisource sensors</strong>, intercommunication, and external-related information (machining equipment components). </td>
                <td> Diverse sampling frequencies: <strong>Vibration</strong> (<strong>10 kHz to 100 kHz</strong>). </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf" target="_blank">1_(done)(irene)Industrial_Big_Data_in_an_Industry_4.0_Environment_Challenges_Schemes_and_Applications_for_Predictive_Maintenance.pdf</a></td>
            </tr>
            <tr>
                <td> Cristina Orsolin Klingenberg, Marco Antonio Viana Borges and José Antonio Valle Antunes Jr </td>
                <td> Industry 4.0 as a data-driven paradigm: a systematic literature review on technologies </td>
                <td> 2019 </td>
                <td> <strong>Corpus documents</strong> (119 articles) covering technologies, refer to Table X, (gruped technologies). </td>
                <td> Corpus collected from searching <strong>EBSCOhost, Web of Science, and ScienceDirect</strong> databases. </td>
                <td> Survey period covered literature published up to <strong>July 2017</strong>. </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)Industry4%20as%20data-driven%20and%20technologies%202021.pdf" target="_blank">1_(done)(irene)Industry4 as data-driven and technologies 2021.pdf</a></td>
            </tr>
            <tr>
                <td> Robert X. Gao, Jorg Kruger, Marion Merklein, Hans-Christian Mohring, Jòzsef Vàncza </td>
                <td> Artificial Intelligence in manufacturing: State of the Art, Perspectives, and Future Directions </td>
                <td> 2024 </td>
                <td> <strong>In-process sensing data</strong>, <strong>time series data</strong>, <strong>image data</strong>, and <strong>acoustic signals</strong>. </td>
                <td> Data derived from various <strong>manufacturing processes</strong> (e.g., milling tools). </td>
                <td> Time series data. Tool wear prediction is guided to increase monotonically as <strong>cutting cycle</strong> increases. </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf" target="_blank">1_(done)(irene)_ArtificialIntelligence_In_manufacturing_state_of_art_futuredirections.pdf</a></td>
            </tr>
            <tr>
                <td> Lian Duan, Li Da Xu </td>
                <td> Data Analytics and Industry 4.0: Survey </td>
                <td> 2021 </td>
                <td> <strong>Big Data</strong>, including <strong>historical data</strong>, <strong>structured</strong>, <strong>semi-structured</strong>, and <strong>unstructured data</strong>. CSV, JSON, XML. </td>
                <td> The survey's own analysis data sources: <strong>Scopus data</strong> and <strong>Google Scholar data</strong>. </td>
                <td> The analysis of trends covers the period from <strong>2014 to 2022</strong>. Data warehouses save <strong>historical data</strong>. </td>
                <td><a href="../2_Papers%20to%20review/1_(done)(irene)data%20analytics%20industry4%20survey%202024.pdf" target="_blank">1_(done)(irene)data analytics industry4 survey 2024.pdf</a></td>
            </tr>
            <tr>
                <td> Sebastian Richard Newrzella, David W. Franklin, and Sultan Haider </td>
                <td> 5-Dimension Cross-Industry Digital Twin Applications Model and Analysis of Digital Twin Classification Terms and Models </td>
                <td> 2021 </td>
                <td> <strong>Product-instance-centric information</strong> necessary for digital continuity, real-time data, engineering data, simulation data, and operational data. </td>
                <td> Data related to the <strong>USAF digital thread initiative</strong>(on the references, else not explicitly mentioned). </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf" target="_blank">1_5-Dimension_Cross-Industry_Digital_Twin_Applications_Model_and_Analysis_of_Digital_Twin_Classification_Terms_and_Models.pdf</a></td>
            </tr>
            <tr>
                <td> Weiming Liu, Chen Zhang, Bin Yu, Yitong Li </td>
                <td> A General Multi-Source Data Fusion Framework </td>
                <td> 2019 </td>
                <td> <strong>Multi-source structured data</strong>, <strong>semi-structured data</strong>, and <strong>unstructured data</strong>. Data models fused: <strong>paper data model</strong> and <strong>college data model</strong>. Unified format: <strong>RDF</strong> Resource  Description Framework, Textual data. </td>
                <td> <strong>Relational database</strong>, <strong>Online encyclopedias, blogs, and other Web sites</strong>. </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/1_A%20General%20Multi-source%20data%20fusion%20framework.pdf" target="_blank">1_A General Multi-source data fusion framework.pdf</a></td>
            </tr>
            <tr>
                <td> Jun Wang, Xiaohan Li, Huading Jia, Shiyu Ji, Jinghua Tan </td>
                <td> A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion </td>
                <td> 2022 </td>
                <td> <strong>Multi-source heterogeneous data</strong> including <strong>Transaction data</strong>, <strong>News texts</strong>, and <strong>Graphical indicators</strong> (K-line, 5-day EMA, 10-day EMA). </td>
                <td> <strong>China Stock Market & Accounting Research (CSMAR) database</strong>. </td>
                <td> Data range from <strong>2013-01-11 to 2019-11-25</strong>. Transaction data uses features aggregated over <strong>5 trading days</strong>. </td>
                <td><a href="../2_Papers%20to%20review/1_A%20graph%20neural%20network-based%20stock%20forecasting%20method%20utilizing%20multi-source%20heterogeneous%20data%20fusion.pdf" target="_blank">1_A graph neural network-based stock forecasting method utilizing multi-source heterogeneous data fusion.pdf</a></td>
            </tr>
            <tr>
                <td> Qinglin Qi, Fei Tao, Tianliang Hu, Nabil Anwer, Ang Liu, Yongli Wei, Lihui Wang, A. Y.C. Nee </td>
                <td> Enabling technologies and tools for digital twin </td>
                <td> 2021 </td>
                <td> <strong>Raw data</strong> (incomplete, unstructured, noisy, fuzzy, and random). Stored data types include <strong>semi-structured and unstructured data</strong>. Focus on the tools for data processing, check the tables included in the paper. </td>
                <td> Requires a <strong>real-time read-write distributed database</strong>. Mentions using tools like <strong>FEA software ANSYS</strong>. </td>
                <td> Requires <strong>real-time</strong> data processing and storage. </td>
                <td><a href="../2_Papers%20to%20review/1_Enabling%20technologies%20and%20tools%20for%20digital%20twin.pdf" target="_blank">1_Enabling technologies and tools for digital twin.pdf</a></td>
            </tr>
            <tr>
                <td> Junhao Zhu, Yuren Mao, Lu Chen, Congcong Ge, Ziheng Wei, Yunjun Gao </td>
                <td> FusionQuery: On-demand Fusion Queries over Multi-source Heterogeneous Data </td>
                <td> 2024 </td>
                <td> <strong>Multi-source heterogeneous data</strong>. Specific formats: <strong>JSON, 210KG, CSV, and XML</strong>. Datasets cover <strong>Movie, Book, Flight, and Stock</strong> data. </td>
                <td> <strong>Four real-world benchmark datasets</strong> collected from various sources (<strong>IMDb</strong> and <strong>wikidata</strong>). </td>
                <td> Framework is <strong>adaptive to frequent data updates</strong>; performance measured against typical update interval of <strong>real-world data lakes</strong>. </td>
                <td><a href="../2_Papers%20to%20review/1_FusionQuery-On-demand%20Fusion%20Queries.pdf" target="_blank">1_FusionQuery-On-demand Fusion Queries.pdf</a></td>
            </tr>
            <tr>
                <td> Simon Kamm, Nasser Jazdi, Michael Weyrich </td>
                <td> Knowledge Discovery in Heterogeneous and Unstructured Data of Industry 4.0 Systems: Challenges and Approaches </td>
                <td> 2021 </td>
                <td> <strong>Heterogeneous data</strong> (structural/syntactical variation and semantic variation) and <strong>unstructured data</strong>. Includes different types of <strong>sensor data</strong>, Optical, Acoustic and others. </td>
                <td> Data isolated in separate <strong>"data silos"</strong>. Sources originate from <strong>multiple sensors from different companies</strong>, not explicitly mentioned. </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/1_Knowledge%20discovery%20in%20heterogeneous%20and%20unstructured%20data.pdf" target="_blank">1_Knowledge discovery in heterogeneous and unstructured data.pdf</a></td>
            </tr>
            <tr>
                <td> Theofanis P. Raptis, Andrea Passarella, Marco Conti </td>
                <td> Data Management in Industry 4.0: State of the Art and Open Challenges </td>
                <td> 2019 </td>
                <td> Data characterized by <strong>volume, variety, traffic, and criticality</strong>. Examples include <strong>machine energy consumption profiles</strong>, <strong>vibration data</strong>, and data derived from <strong>RFID tags</strong>. </td>
                <td> Data is sourced from <strong>networked industrial environments</strong>, <strong>industrial sensors</strong>, and acquired using <strong>FPGA-based reconfigurable data acquisition systems</strong>. </td>
                <td> Data is collected for <strong>archival and in real time</strong>. Real-time data acquisition is achieved via <strong>FPGA-based reconfigurable data acquisition systems</strong>. </td>
                <td><a href="../2_Papers%20to%20review/2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf" target="_blank">2_(done)(irene)Data_Management_in_Industry_4.0_State_of_the_Art_and_Open_Challenges.pdf</a></td>
            </tr>
            <tr>
                <td> Sultan Baimukhanov, Hashim Ali, Adnan Yazici </td>
                <td> Enhancing ML-based anomaly detection in data management for security through integration of IoT, cloud, and edge computing </td>
                <td> 2025 </td>
                <td> <strong>IoT-generated information</strong> and <strong>IoT sensor readings</strong>. </td>
                <td> <strong>IoT devices</strong> transmitting data through <strong>Edge and Cloud computing</strong> environments. </td>
                <td> Mentions capability for <strong>real-time monitoring</strong>. </td>
                <td><a href="../2_Papers%20to%20review/2_Enhancing_MLbased%20anomaly%20detection%20in%20data%20management%20for%20security%20on%20integration%20of%20iot.pdf" target="_blank">2_Enhancing_MLbased anomaly detection in data management for security on integration of iot.pdf</a></td>
            </tr>
            <tr>
                <td> Jing Gao, Peng Li, Zhikui Chen, and Jianing Zhang </td>
                <td> A Survey on Deep Learning for Multimodal Data Fusion </td>
                <td> 2020 </td>
                <td> <strong>Multimodal data</strong>. Examples include <strong>MRI and PET</strong> data (images), <strong>pose views</strong> features, and fusion of <strong>visual systems data</strong> with <strong>unannotated text</strong>. </td>
                <td> Sources relate to medical imaging (MRI/PET) and general visual systems. </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/2_deeplearning_multimodal.pdf" target="_blank">2_deeplearning_multimodal.pdf</a></td>
            </tr>
            <tr>
                <td> Jun Wang, Xiaohan Li, Huading Jia, Tao Peng </td>
                <td> A graph-based approach to multi-source heterogeneous information fusion in stock market </td>
                <td> 2022 </td>
                <td> <strong>Multi-source heterogeneous information</strong> consisting of <strong>Transaction data</strong> (financial time series) and <strong>Stock news text data</strong>. </td>
                <td> <strong>CMSAR database (China Stock Market & Accounting Research Database)</strong>. News text data obtained via <strong>internet crawling</strong>. </td>
                <td> Data ranges from <strong>January 1, 2016, to December 31, 2020</strong>. </td>
                <td><a href="../2_Papers%20to%20review/2_graph-based%20multisource%20heterogeneous%20information%20fusion%20for%20stockmarket.pdf" target="_blank">2_graph-based multisource heterogeneous information fusion for stockmarket.pdf</a></td>
            </tr>
            <tr>
                <td> Bentian Li, Dechang Pi, Yunxia Lin, Izhar Ahmed Khan, Lin Cui </td>
                <td> Multi-Source Information Fusion Based Heterogeneous Network Embedding </td>
                <td> 2020 </td>
                <td> <strong>Heterogeneous network data</strong> composed of authors, papers, and venues (nodes and relationships). Node features include <strong>title content</strong> (<strong>text data</strong>). </td>
                <td> Two real-world network datasets: <strong>DBLP Heterogeneous Network</strong> and <strong>ACM Heterogeneous Network</strong>. </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/2_multisourceinformationfusionbasednetworkingembedding.pdf" target="_blank">2_multisourceinformationfusionbasednetworkingembedding.pdf</a></td>
            </tr>
            <tr>
                <td> Zhengjing Ma, Gang Mei, Salvatore Cuomo, Francesco Piccialli </td>
                <td> Heterogeneous Data Fusion Considering Spatial Correlations using Graph Convolutional Networks and its Application in Air Quality Prediction </td>
                <td> 2021 </td>
                <td> <strong>Continuous heterogeneous data</strong> (<strong>meteorological monitoring data</strong> and <strong>air quality monitoring data</strong>). Data is represented as <strong>graph-structured data</strong> and <strong>time series data</strong>. </td>
                <td> Real dataset related to air quality in Beijing, collected from the <strong>Harvard Dataverse</strong> (<strong>35 meteorological stations</strong> and <strong>17 air quality stations</strong>). </td>
                <td> Data records are collected <strong>every hour</strong>. Collection period: <strong>January 1, 2017, to February 1, 2018</strong>. </td>
                <td><a href="../2_Papers%20to%20review/3_datafusion_graphCNN.pdf" target="_blank">3_datafusion_graphCNN.pdf</a></td>
            </tr>
            <tr>
                <td> Hong Zhang, Kun Jiang, Chuanqi Cheng, Jie Cao, Wenyue Zhang </td>
                <td> Multi-source Heterogeneous Data Fusion Model Based on FC-SAE </td>
                <td> 2022 </td>
                <td> <strong>Multi-source heterogeneous time series data</strong>. Includes <strong>time series data</strong> (daily taxi traveling data), <strong>event text description data</strong> (unstructured text), and <strong>weather data</strong>. </td>
                <td> <strong>Taxi traveling record data set</strong> related to the transportation domain. </td>
                <td> Original data is aggregated to produce <strong>daily taxi traveling data</strong>. Training set: <strong>January 2013 to September 2014</strong> , Validation set: <strong>October to December 2014</strong>. Test set: <strong>January 2015 to June 2016</strong>. </td>
                <td><a href="../2_Papers%20to%20review/4_datafusion_multisource.pdf" target="_blank">4_datafusion_multisource.pdf</a></td>
            </tr>
            <tr>
                <td> Kader Pustu-Iren, Gerrit Bruns, Ralph Ewerth </td>
                <td> A Multimodal Approach for Semantic Patent Image Retrieval </td>
                <td> 2021 </td>
                <td> <strong>Multimodal data</strong> combining <strong>Textual Features</strong> (keywords, titles, etc.) and <strong>Visual Features</strong> (from patent images). </td>
                <td> <strong>Patent documents</strong>. </td>
                <td> Not explicitly mentioned. </td>
                <td><a href="../2_Papers%20to%20review/5_multimodal_patentimage.pdf" target="_blank">5_multimodal_patentimage.pdf</a></td>
            </tr>
            <tr>
                <td> Jeonghun Jee, Sanghyun Park, Sungjoo Lee </td>
                <td> Potential of patent image data as technology intelligence source </td>
                <td> 2022 </td>
                <td> <strong>Patent image data</strong> (text extracted from <strong>block diagrams</strong>), and <strong>Descriptive patent data</strong>. Analysis uses a <strong>Binary patent-to-keyword matrix</strong>. </td>
                <td> Data extracted from <strong>patent documents</strong>. Images sourced from the <strong>Google Patent site</strong>. </td>
                <td> Patents grouped into four periods for <strong>time series analysis</strong>: <strong>P1 (2010–2011)</strong>, <strong>P2 (2012–2013)</strong>, <strong>P3 (2014–2015)</strong>, and <strong>P4 (2016–2017)</strong>. </td>
                <td><a href="../2_Papers%20to%20review/6_patentimage.pdf" target="_blank">6_patentimage.pdf</a></td>
            </tr>
            <tr>
                <td> Wenguang Lin, Wenchao Yan, Zhizhen Chen, Renbin Xiao </td>
                <td> Research on product appearance patent spatial shape recognition for multi-image feature fusion </td>
                <td> 2023 </td>
                <td> <strong>Image data</strong> focused on <strong>appearance design patent images</strong>. Features analyzed include <strong>shape features</strong> and <strong>texture features</strong>. </td>
                <td> Design patent base/documents, Smart buds patent Data base. </td>
                <td> Smart buds patent Data base from January 2011 till December 2020 </td>
                <td><a href="../2_Papers%20to%20review/7_patentimage_spatialshapes.pdf" target="_blank">7_patentimage_spatialshapes.pdf</a></td>
            </tr>
            <tr>
                <td> Lili Zhang, Yuxiang Xie, Luan Xidao, Xin Zhang </td>
                <td> Multi-source heterogeneous data fusion </td>
                <td> 2018 </td>
                <td> <strong>Multi-source heterogeneous information</strong>, discussion on <strong>Multi-source domain adaptation</strong>, <strong>cross-media big data</strong>, and <strong>multimedia big data</strong>. </td>
                <td> Sources implicitly include generalized big data systems and reference points. </td>
                <td> Not explicitly mentioned (Used). </td>
                <td><a href="../2_Papers%20to%20review/8_Multi-source_heterogeneous_data_fusion.pdf" target="_blank">8_Multi-source_heterogeneous_data_fusion.pdf</a></td>
            </tr>
            <tr>
				<td>Amit Mithal, Blessy Thankachan</td>
				<td>A Comprehensive Review on Blockchain-based Systems for Groundwater Conservation and Wastewater Management</td>
				<td>2025</td>
				<td>Water quality monitoring data (e.g., pH, dissolved oxygen, turbidity), sensor data (IoT-based monitoring), groundwater level data, real-time consumption records, transactional data (for resource trading/compliance), hydrological model outputs, and ML/DL derived data (for anomaly detection, pollution prediction).</td>
				<td>IoT sensing infrastructure (distributed across water networks), regulatory databases, smart meters, hydrological monitoring stations, satellite data (used in some reviewed papers for context/modeling), and the Blockchain ledger itself (for secure, validated records).</td>
				<td>Real-time or near-real-time sensor data acquisition (depending on the IoT implementation), with archival records stored on the blockchain.</td>
				<td><a href="../2_Papers%20to%20review/1_(Important)A review on blockchain for water mngmnt.pdf" target="_blank">1_(Important)A review on blockchain for water mngmnt.pdf</a></td>
			</tr>
            <tr>
				<td>Nikita V. Golovastikov, Nikolay L. Kazanskiy, Svetlana N. Khonina</td>
				<td>Optical Fiber-Based Structural Health Monitoring: Advancements, Applications, and Integration with Artificial Intelligence for Civil and Urban Infrastructure</td>
				<td>2025</td>
				<td>Distributed and localized sensor data (Strain, Temperature, Vibration), Time-series data, Displacement/Deformation measurements, Acoustic Emission data, Multi-sensor heterogeneous data streams, and Annotated data (for damage detection/classification models).</td>
				<td>Fiber Optic Sensors (FOS), including Fiber Bragg Grating (FBG) sensors and Distributed Fiber Optic Sensors (DFOS) embedded within civil infrastructure (bridges, tunnels, buildings). Data Acquisition Systems (DAS) and related AI processing units.</td>
				<td>High-frequency (kHz range) distributed sensing data, allowing for real-time monitoring of dynamic structural responses (e.g., vibration analysis).</td>
				<td><a href="../2_Papers%20to%20review/3_Optical Fiber-Based Structural Health Monitoring.pdf" target="_blank">3_Optical Fiber-Based Structural Health Monitoring.pdf</a></td>
			</tr>
            <tr>
				<td>Milton Samadder, Anup Kumar Barman, Shiladitya Munshi, Utpal Madhu</td>
				<td>Leveraging Directed Acyclic Graphs for Advanced Ensemble Learning in Predictive Maintenance for Industry 4.0</td>
				<td>2025</td>
				<td>Time series sensor data (e.g., vibration, temperature, pressure), Failure labels (RUL or binary), Historical run-to-failure data, Operational parameters (speed, load), and Derived features from raw sensor signals (e.g., statistical features, frequency domain features).</td>
				<td>Industrial equipment sensors (IIoT), NASA Ames Prognostics Data Repository (specifically Turbofan Engine Degradation Simulation Dataset mentioned as a common benchmark), and specialized machinery databases.</td>
				<td>High-frequency time-series data (for capturing machine health changes), with specific sensor rates depending on the equipment (e.g., daily snapshots for RUL, or high kHz for vibration data).</td>
				<td><a href="../2_Papers%20to%20review/1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf" target="_blank">1_(important)Leveraging_Directed_Acyclic_Graphs_for_Advanced_Ensemble_Learning_in_Predictive_Maintenance_for_Industry_4.0.pdf</a></td>
			</tr>
            <tr>
				<td>Pruthvi Prashanth Mattihalli, H G Pratheek Gowda, H N Nisarga, Bhoomika G K, Dr. Geetha Kiran A</td>
				<td>HydroSense 2.0: An IoT-Based Smart Water Quality Monitoring and Alert System with Machine Learning and Cloud Integration</td>
				<td>2025</td>
				<td>Water quality sensor readings (pH, Temperature, Turbidity, Total Dissolved Solids - TDS), Historical training data (labeled for quality/contamination status), and Machine Learning model output (classification/alert status).</td>
				<td>IoT deployment using ESP32 microcontroller interfaced with industry-grade physical sensors (pH, Temperature, Turbidity, TDS probes) deployed in water bodies. Data is transmitted to an integrated Cloud platform (e.g., Google Cloud/AWS) for storage and processing.</td>
				<td>Real-time or near-real-time acquisition (data streamed from sensors every few seconds/minutes to the cloud platform).</td>
				<td><a href="../2_Papers%20to%20review/1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf" target="_blank">1_(important)HydroSense_2.0_An_IoT-Based_Smart_Water_Quality_Monitoring_and_Alert_System_with_Machine_Learning_and_Cloud_Integration.pdf</a></td>
			</tr>
            <tr>
				<td>Arman Malekloo, Ekin Ozer, Mohammad AlHamaydeh and Mark Girolami</td>
				<td>Machine learning and structural health monitoring overview with emerging technology and high-dimensional data source highlights</td>
				<td>2021</td>
				<td>High-dimensional data, Time-series data (vibration, strain, acceleration, displacement), Image/Video data (from UAVs and cameras), LiDAR/Point cloud data, Multi-sensor heterogeneous data, Spatiotemporal data, Seismic data, Acoustic data, Thermal data.</td>
				<td>Conventional SHM sensors (accelerometers, strain gauges, fiber optics), Wireless Sensor Networks (WSNs), Internet of Things (IoT) sensors, Unmanned Aerial Vehicles (UAVs), Smartphones, External databases (e.g., climate, traffic, earthquake data).</td>
				<td>Focuses on near real-time and online assessment; periodicity is highly diverse and often high-frequency (e.g., dynamic monitoring) depending on the Structural Health Monitoring (SHM) method.</td>
				<td><a href="../2_Papers%20to%20review/3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf" target="_blank">3_malekloo-et-al-2021-machine-learning-and-structural-health-monitoring-overview-with-emerging-technology-and-high.pdf</a></td>
			</tr>
            <tr>
				<td>Xiangtian Nie, Tianyu Fan, Bo Wang, Zhiyong Li, Achyut Shankar, Adhiyaman Manickam</td>
				<td>Big Data analytics and IoT in Operation safety management in Under Water Management</td>
				<td>2020</td>
				<td>Operational data (e.g., water usage, flow rates), Environmental sensor data (e.g., water quality parameters), SCADA data, Big Data streams.</td>
				<td>Internet of Things (IoT) sensors, Wireless Sensor Networks (WSN), Supervisory Control and Data Acquisition (SCADA) systems, Raspberry Pi remote monitoring devices.</td>
				<td>The system is designed for real-time monitoring and proactive control, implying continuous or near real-time data collection.</td>
				<td><a href="../2_Papers%20to%20review/2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf" target="_blank">2_BigDataanalyticsandIoTinOperationsafetymanagementinUnderWater.pdf</a></td>
			</tr>
            <tr>
				<td>N. Donratanapat, S. Samadi, J.M. Vidal, S. Sadeghi Tabas</td>
				<td>A national scale big data analytics pipeline to assess the potential impacts of flooding on critical infrastructures and communities</td>
				<td>2020</td>
				<td>Big Data (heterogeneous data streams), Social Media data (Twitter/Tweets for crowd intelligence, text data for Natural Language Processing), Geographic Information System (GIS) data (spatial flood data, critical infrastructure locations), Historical and Real-time event data.</td>
				<td>Multiple servers/Big Data infrastructure, Internet of Things (IoT) devices, Social media platforms (Twitter/X), Historical flood models and records, U.S. Geological Survey (USGS) for elevation and land data.</td>
				<td>Designed to gather and analyze data during both historical and **real-time** events, implying continuous or near real-time data ingestion for situational awareness.</td>
				<td><a href="../2_Papers%20to%20review/2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf" target="_blank">2_Anationalscalebigdataanalyticspipelinetoassessthepotentialimpactsof.pdf</a></td>
			</tr>
            <tr>
				<td>Inês Figueiredo, Paulo Esteves, Paulo Cabrita</td>
				<td>Water wise – a digital water solution for smart cities and water management entities</td>
				<td>2021</td>
				<td>Water demand data, Operational water supply network data (e.g., flow, pressure), Energy consumption data (Water-Energy Nexus), Financial data, Sensor data (from IoT infrastructure).</td>
				<td>IoT sensors and devices for real-time monitoring, SCADA systems (implied for operational data), external systems for energy data and financial/billing information.</td>
				<td>Designed for **real-time monitoring** of the urban water cycle, supporting a Decision Support System (DSS).</td>
				<td><a href="../2_Papers%20to%20review/1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf" target="_blank">1_(Important)Waterwise–adigitalwatersolutionforsmartcitiesandwater.pdf</a></td>
			</tr>
            <tr>
				<td>Gerasimos Antzoulatos, Christos Mourtzios, Panagiota Stournara, Ioannis-Omiros Kouloglou, Nikolaos Papadimitriou, Dimitrios Spyrou, Alexandros Mentes, Efstathios Nikolaidis, Anastasios Karakostas, Dimitrios Kourtesis, Stefanos Vrochidis and Ioannis Kompatsiaris</td>
				<td>Making urban water smart: the SMART-WATER solution</td>
				<td>2020</td>
				<td>Water consumption data (e.g., flow, volume), Real-time telemetry data, Smart metering data, Network state and operational data, Big Data streams (for predictive analytics).</td>
				<td>Internet of Things (IoT) sensors and devices, Low Power Wide Area Network (LPWAN) infrastructure, Smart meters, Water utility SCADA/telemetry systems.</td>
				<td>Designed for **remote telemetry and control**, implying continuous or near real-time data acquisition for monitoring and predictive analytics.</td>
				<td><a href="../2_Papers%20to%20review/2_MakingurbanwatersmarttheSMART-WATERsolution.pdf" target="_blank">2_MakingurbanwatersmarttheSMART-WATERsolution.pdf</a></td>
			</tr>
            <tr>
				<td>Md Shamsur Rahim, Khoi Anh Nguyen, Rodney Anthony Stewart, Damien Giurco and Michael Blumenstein</td>
				<td>Machine Learning and Data Analytic Techniques in Digital Water Metering: A Review</td>
				<td>2020</td>
				<td>Water consumption data (e.g., flow rate, volume), Time-series data, Customer metadata/demographics (for consumption pattern classification), Meter readings (often electronic and frequent).</td>
				<td>Digital water meters (or intelligent water meters), Smart metering infrastructure.</td>
				<td>High-frequency data (digital meters can frequently send consumption information electronically), suitable for **real-time** applications like leakage detection and consumption pattern analysis.</td>
				<td><a href="../2_Papers%20to%20review/2_MachineLearningandDataAnalyticTechniquesin.pdf" target="_blank">2_MachineLearningandDataAnalyticTechniquesin.pdf</a></td>
			</tr>
            <tr>
				<td>Sunil Sinha and Lee Sears</td>
				<td>Collection and Compilation of Water Pipeline Field Performance Data</td>
				<td>2017</td>
				<td>Pipeline Reliability Performance Data, Infrastructure Inventory Data (material type: cast iron, ductile iron, concrete, steel, PVC, AC, etc.), Physical Data, Operational Data, Environmental Data, Social Data, Financial Data, Condition Assessment Data.</td>
				<td>U.S. Bureau of Reclamation (USBR), U.S., Canadian, and Australian Water Utilities, Web-based, GIS-enabled national pipeline database (PIPEID), Various data collection projects (Phase I).</td>
				<td>The data collected is largely **static** (infrastructure inventory) and **historical** (reliability performance), with a goal of future integration to support dynamic modeling.</td>
				<td><a href="../2_Papers%20to%20review/2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf" target="_blank">2_CollectionandCompilationofWaterPipelineFieldPerformance.pdf</a></td>
			</tr>
        </tbody>
    </table>
</div>
"""

display(HTML(content_html))
# Out:
# <div style="width: 100%; height: 600px; overflow: auto; border: 2px solid #007bff; padding: 5px;">
#     <style>
#         /* Ensures the table is wide to enable horizontal scrolling if needed */
#         table { width: 100%; border-collapse: collapse; font-size: 14px; }
#
#         /* Border color set to #bbb (grayish) */
#         th, td { border: 1px solid #bbb; padding: 8px; text-align: left; vertical-align: top; }
#
#         /* Header background, bold, and text color set to black */
#         th { background-color: #f2f2f2; font-weight: strong; color: black; }
#
#         /* Style the wide columns (Data types, Sources) to be more readable */
#         td:nth-child(4), td:nth-child(5) { min-width: 250px; }
#
#         /* MODIFIED: Source File Name column to break words and be narrower */
#         td:nth-child(7) {
#             min-width: 150px;
#             word-break: break-all;
#         }
#     </style>
#
#     <table>
#         <thead>
#             <tr>
# ...
